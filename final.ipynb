# %%
import pandas as pd
from geopy.distance import geodesic
import matplotlib.pyplot as plt
import re
from ast import literal_eval

# %% [markdown]
# !pip install pandas
# !pip install geopy
# !pip install matplotlib
# !pip install re

# %% [markdown]
# ## Get CSV files

# %%
Train = pd.read_csv('./Train Data set.csv')
Metro = pd.read_csv('./Metro Data set.csv')
Bus = pd.read_csv('./Bus Data set.csv')
Auto = pd.read_csv('./Auto Data set.csv')

# %% [markdown]
# # Checking Sizes of Data

# %%
print(Train.shape , Metro.shape, Bus.shape, Auto.shape)
# Out:
# (321, 3) (40, 3) (1660, 3) (1660, 3)

# %% [markdown]
# # Helper Functions

# %%
def Merge_Nodes(point1 , point2): #are_close_points
    if (geodesic(point1, point2).meters <= 100):
        return True 
    else :
        return False

# %%
def getNodes(Transport): #compress_coordinate
    NodePoints = []
    for i in range(Transport.shape[0]) :
        NodePoints.append((Transport['lat'][i], Transport['long'][i]))
    return NodePoints

# %% [markdown]
# ## Get List of Nodes

# %%
TrainNodes = getNodes(Train)

# %%
MetroNodes = getNodes(Metro)

# %%
BusNodes = getNodes(Bus)

# %%
AutoNodes = getNodes(Auto)

# %% [markdown]
# BusNodes

# %% [markdown]
# # Combining nodes in range of 100 meters

# %%
Nodes = {}

# %%
def getCloseNodes(Node_List_1, Node_List_2): # collect_close_vertex
    List_1 = []
    List_2 = []
    for i in range(len(Node_List_1)):
        for j in range(len(Node_List_2)):
            if Merge_Nodes(Node_List_1[i],Node_List_2[j]):
                List_1.append(i)
                List_2.append(j)
    return [List_1,List_2]

# %%
def add_Transport(df): # populate_Nodes_with_Transport
    dfNodes = getNodes(df)
    globalNodes = []
    
    for node in Nodes:
        globalNodes.append(node)
        
    b = getCloseNodes(globalNodes, dfNodes)
    
    for i in range (len (b[0])):
        Nodes[ globalNodes[b[0][i]] ].append(df.iloc[:,0][b[1][i]])
    
    for i in range (len(dfNodes)):
        if i in b[1]:
            continue
        Nodes[dfNodes[i]] = [ df.iloc[:,0][i] ]

# %%
a = getCloseNodes(TrainNodes, MetroNodes)

for i in range (len (a[0])):
    Nodes[ TrainNodes[a[0][i]] ] = [ Metro.iloc[:,0][a[1][i]], Train.iloc[:,0][a[0][i]] ]
    
for i in range (len(TrainNodes)):
    if i in a[0]:
        continue
    Nodes[TrainNodes[i]] = [ Train.iloc[:,0][i] ]
    
for i in range (len(MetroNodes)):
    if i in a[1]:
        continue
    Nodes[MetroNodes[i]] = [ Metro.iloc[:,0][i] ]

# %%
#add new transport here 👇👇👇👇👇👇
add_Transport(Bus)
add_Transport(Auto)

# %%
Nodes
# Out:
# {(23.64797, 88.128418): ['KATWA JN TRAIN STOP'],
#  (23.6014, 88.170403): ['DAINHAT TRAIN STOP'],
#  (23.592127, 88.201091): ['SAHEBTALA TRAIN STOP'],
#  (23.608841, 88.360641): ['AGRADWIP TRAIN STOP'],
#  (23.547199, 88.252296): ['PATULI TRAIN STOP'],
#  (22.56327, 88.40707): ['BELERHAT TRAIN STOP'],
#  (23.618061, 88.015467): ['LAKSHMIPUR TRAIN STOP'],
#  (23.481474, 88.320293): ['MERTALA PHALEYA TRAIN STOP'],
#  (23.44511, 88.311493): ['PURBASTHALI TRAIN STOP'],
#  (23.44414, 88.32613): ['BHANDARTIKURI TRAIN STOP'],
#  (23.420361, 88.347977): ['BISHNUPRIYA TRAIN STOP'],
#  (23.39919, 88.36352): ['NABADWIP DHAM TRAIN STOP'],
#  (23.3354, 88.324699): ['SAMUDRAGARH TRAIN STOP'],
#  (23.2777, 88.311798): ['DHATRIGRAM TRAIN STOP'],
#  (23.236093, 88.289629): ['BAGHNAPARA TRAIN STOP'],
#  (23.224859, 88.348221): ['AMBIKA KALNA TRAIN STOP'],
#  (23.202867, 88.410031): ['GUPTIPARA TRAIN STOP'],
#  (23.182817, 88.427839): ['BEHULA TRAIN STOP'],
#  (23.139232, 88.432816): ['SOMRA BAZAR TRAIN STOP'],
#  (23.13035, 88.470573): ['BALAGARH TRAIN STOP'],
#  (22.83296, 88.622841): ['JIRAT TRAIN STOP'],
#  (23.06581, 88.44258): ['KHAMARGACHHI TRAIN STOP'],
#  (23.03978816, 88.43219407): ['DUMURDAHA TRAIN STOP'],
#  (23.00318, 88.410118): ['KUNTIGHAT TRAIN STOP'],
#  (22.984699, 88.397903): ['TRIBENI TRAIN STOP'],
#  (22.95509, 88.403152): ['BANSBERIA TRAIN STOP'],
#  (22.923057, 88.378222): ['BANDEL JN TRAIN STOP'],
#  (22.896255, 88.246117): ['HOOGHLY TRAIN STOP'],
#  (22.8958, 88.395714): ['CHINSURAH TRAIN STOP'],
#  (22.869012, 88.362347): ['CHANDERNAGOR TRAIN STOP'],
#  (22.847059, 88.349998): ['MANKUNDU TRAIN STOP'],
#  (22.8278595, 88.34151362): ['BHADRESHWAR TRAIN STOP'],
#  (22.774691, 88.31237): ['BAIDYABATI TRAIN STOP'],
#  (22.774395, 88.328723): ['SEORAPHULI JN TRAIN STOP'],
#  (22.73794, 88.34449): ['SERAMPORE TRAIN STOP'],
#  (22.724401, 88.328789): ['RISHRA TRAIN STOP'],
#  (22.70438, 88.326012): ['KONNAGAR TRAIN STOP'],
#  (22.51096, 88.33666): ['NEW ALIPORE TRAIN STOP'],
#  (22.66926, 88.34552): ['UTTARPARA TRAIN STOP'],
#  (22.649509, 88.336995): ['BALLY TRAIN STOP'],
#  (22.636769, 88.339787): ['BELUR TRAIN STOP'],
#  (22.625071, 88.329514): ['LILUAH TRAIN STOP'],
#  (22.59577, 88.263641): ['HOWRAH TRAIN STOP',
#   'PTS BUS STOP',
#   'P.T.S. MORE BUS STOP',
#   'PTS AUTO STOP',
#   'P.T.S. MORE AUTO STOP'],
#  (22.533279, 88.304878): ['TIKIAPARA TRAIN STOP'],
#  (22.60393, 88.321449): ['DASNAGAR TRAIN STOP'],
#  (22.592932, 88.299263): ['RAMRAJATALA TRAIN STOP'],
#  (22.589487, 88.301606): ['SANTRAGACHI JN TRAIN STOP'],
#  (22.60849, 88.26722): ['BANKRA NAYABAZAR TRAIN STOP'],
#  (22.618541, 88.296478): ['KONA TRAIN STOP'],
#  (22.622283, 88.266454): ['DANSI TRAIN STOP'],
#  (22.617689, 88.248032): ['MAKARDAHA TRAIN STOP'],
#  (22.60296, 88.20627): ['DOMJUR ROAD TRAIN STOP'],
#  (22.602909, 88.233917): ['DOMJUR TRAIN STOP'],
#  (22.656391, 88.182632): ['DAKSHINBARI TRAIN STOP'],
#  (22.674681, 88.174232): ['BARGACHIA TRAIN STOP'],
#  (22.650869, 88.127068): ['PANTIHAL TRAIN STOP'],
#  (22.671721, 88.097076): ['MUNSHIRHAT TRAIN STOP'],
#  (22.643509, 88.091484): ['MAHENDRALALNAGAR TRAIN STOP'],
#  (22.554874, 88.316564): ['SHALIMAR TRAIN STOP',
#   'SHALIMAR STATION BUS STOP',
#   'SHALIMAR STATION AUTO STOP'],
#  (22.5637, 88.300751): ['PADMAPUKUR TRAIN STOP'],
#  (22.580446, 88.255999): ['MAURIGRAM TRAIN STOP',
#   'MOURIGRAM BUS STOP',
#   'MOURIGRAM AUTO STOP'],
#  (22.59647, 88.225609): ['ANDUL TRAIN STOP'],
#  (22.58119, 88.208138): ['SANKRAIL TRAIN STOP'],
#  (22.548304, 88.19968): ['ABADA TRAIN STOP'],
#  (22.530083, 88.186516): ['NALPUR TRAIN STOP'],
#  (22.502996, 88.16319): ['BAURIA TRAIN STOP'],
#  (22.502939, 88.135178): ['CHENGAIL TRAIN STOP'],
#  (22.479839, 88.113159): ['PHULESWAR TRAIN STOP'],
#  (22.474436, 88.100037): ['ULUBERIA TRAIN STOP'],
#  (22.47953, 88.047302): ['BIRSHIBPUR TRAIN STOP'],
#  (22.47246, 88.014732): ['KULGACHIA TRAIN STOP'],
#  (22.462601, 87.969803): ['BAGNAN TRAIN STOP'],
#  (22.458131, 87.943037): ['GHORAGHATA TRAIN STOP'],
#  (22.453469, 87.914582): ['DEULTI TRAIN STOP'],
#  (22.425079, 87.861038): ['KOLAGHAT TRAIN STOP'],
#  (22.415062, 87.85853): ['MECHEDA TRAIN STOP'],
#  (22.404186, 87.832805): ['NANDAI GAJAN TRAIN STOP'],
#  (22.40241, 87.809377): ['BHOGPUR TRAIN STOP'],
#  (22.399867, 87.774236): ['NARAYAN PAKURIA MURAIL TRAIN STOP'],
#  (22.39259, 87.74277): ['PANSKURA JN TRAIN STOP'],
#  (23.71097, 87.576149): ['KHIRAI TRAIN STOP'],
#  (22.365844, 87.65489): ['HAUR TRAIN STOP'],
#  (22.357271, 87.613465): ['RADHAMOHANPUR TRAIN STOP'],
#  (22.354942, 87.583621): ['DUAN TRAIN STOP'],
#  (22.3577, 87.552803): ['BALICHAK TRAIN STOP'],
#  (22.363649, 87.500782): ['SHYAMCHAK TRAIN STOP'],
#  (22.369532, 87.443126): ['MADPUR TRAIN STOP'],
#  (22.362432, 87.389605): ['JAKPUR TRAIN STOP'],
#  (22.341006, 87.326231): ['KHARAGPUR JN TRAIN STOP'],
#  (22.341471, 87.306648): ['GIRI MAIDAN TRAIN STOP'],
#  (22.375576, 87.294012): ['GOKULPUR TRAIN STOP'],
#  (22.41528, 87.32532): ['MIDNAPORE JN TRAIN STOP'],
#  (22.85067, 87.267982): ['RAGHUNATHBARI TRAIN STOP'],
#  (22.324158, 87.866499): ['RAJGODA TRAIN STOP'],
#  (22.36572, 87.8891): ['SHAHID MATANGINI TRAIN STOP'],
#  (22.2747, 87.920097): ['TAMLUK TRAIN STOP'],
#  (22.221192, 87.95001): ['KESHABPUR TRAIN STOP'],
#  (22.192594, 87.990771): ['SATISH SAMANTA TRAIN STOP'],
#  (22.182299, 87.989688): ['MAHISHDAHAL TRAIN STOP'],
#  (22.152474, 88.089556): ['BARDA TRAIN STOP'],
#  (22.120591, 88.131069): ['BASULYASUTAHATA TRAIN STOP'],
#  (22.07299, 88.143059): ['DURGACHAK TRAIN STOP'],
#  (22.06673, 88.135355): ['DURGACHAK TOWN TRAIN STOP'],
#  (22.067459, 88.137177): ['HALDIA TRAIN STOP'],
#  (22.232422, 87.861481): ['BURDWAN TRAIN STOP'],
#  (23.250433, 87.870544): ['GANGPUR TRAIN STOP'],
#  (23.046261, 88.821037): ['SAKTIGARH TRAIN STOP'],
#  (23.19669, 88.002707): ['PALSIT TRAIN STOP'],
#  (23.18401, 88.030197): ['RASULPUR TRAIN STOP'],
#  (23.180871, 88.069076): ['NIMO HALT TRAIN STOP'],
#  (23.172899, 88.095802): ['MEMARI TRAIN STOP'],
#  (23.335609, 88.644211): ['BAGULA TRAIN STOP'],
#  (23.1439, 88.156998): ['DEBIPUR TRAIN STOP'],
#  (23.221939, 88.353867): ['BAINCHI TRAIN STOP'],
#  (23.106842, 88.215674): ['BAINCHIGRAM TRAIN STOP'],
#  (23.095918, 88.230389): ['SIMLAGARH TRAIN STOP'],
#  (23.070673, 88.269673): ['PUNDOOAH TRAIN STOP'],
#  (23.049919, 88.31987): ['KHANYAN TRAIN STOP'],
#  (23.011119, 88.345683): ['TALANDU TRAIN STOP'],
#  (22.983499, 88.368335): ['MAGRA TRAIN STOP'],
#  (22.95294, 88.381538): ['ADI SAPTAGRAM TRAIN STOP'],
#  (23.0158, 88.41002): ['HOOGHLY GHAT TRAIN STOP'],
#  (22.909719, 88.412845): ['GARIFA TRAIN STOP'],
#  (22.89101, 88.41928): ['NAIHATI JN TRAIN STOP'],
#  (23.17948, 88.009186): ['PALLA ROAD TRAIN STOP'],
#  (22.55797603, 88.37892468): ['CHANCHAL HALT TRAIN STOP'],
#  (23.123581, 88.029701): ['MASAGRAM TRAIN STOP'],
#  (23.11192578, 88.0572021): ['NABAGRAM TRAIN STOP'],
#  (23.027969, 88.051643): ['JAUGRAM TRAIN STOP'],
#  (23.063904, 88.09111): ['JHAPANDANGA TRAIN STOP'],
#  (23.028379, 88.110413): ['GURAP TRAIN STOP'],
#  (23.00699, 88.12109): ['HAJIGARH TRAIN STOP'],
#  (22.974652, 88.13387): ['SIBAICHANDI TRAIN STOP'],
#  (22.933071, 88.152132): ['BELMURI TRAIN STOP'],
#  (22.90514, 88.15868): ['PORABAZAR TRAIN STOP'],
#  (22.880595, 88.176389): ['CHANDANPUR TRAIN STOP'],
#  (23.0364, 88.339401): ['MADHUSUDANPUR TRAIN STOP'],
#  (22.820851, 88.205311): ['KAMARKUNDU JN TRAIN STOP'],
#  (22.789619, 88.208649): ['BALARAMBATI TRAIN STOP'],
#  (22.79215, 88.22312): ['MIRZAPUR-BANKIPUR TRAIN STOP'],
#  (22.76314, 88.25985): ['BARUIPARA TRAIN STOP'],
#  (22.747402, 88.250984): ['BEGAMPUR TRAIN STOP'],
#  (22.719879, 88.26181): ['JANAI ROAD TRAIN STOP'],
#  (22.696175, 88.284442): ['GOBRA TRAIN STOP'],
#  (22.678283, 88.290404): ['DANKUNI JN TRAIN STOP'],
#  (22.661842, 88.318637): ['BELANAGAR TRAIN STOP'],
#  (22.65304, 88.322739): ['RAJCHANDRAPUR TRAIN STOP'],
#  (22.65218, 88.336433): ['BALLY HALT TRAIN STOP'],
#  (22.652816, 88.348336): ['BALLYGHAT TRAIN STOP',
#   'BALLYKHAL BUS STOP',
#   'BALLYKHAL AUTO STOP'],
#  (22.660021, 88.376602): ['DAKSHINESHWAR TRAIN STOP'],
#  (22.64813, 88.37336): ['BARANAGAR ROAD TRAIN STOP'],
#  (22.62488, 88.393174): ['DUM DUM JN TRAIN STOP'],
#  (22.887906, 88.023922): ['TARAKESHWAR TRAIN STOP'],
#  (22.72859, 88.463): ['LOKNATH TRAIN STOP'],
#  (22.85543, 88.07024): ['BAHIRKHANDA TRAIN STOP'],
#  (22.840778, 88.091537): ['KAIKALA TRAIN STOP'],
#  (22.817217, 88.104729): ['HARIPAL TRAIN STOP'],
#  (22.831827, 88.137224): ['MALIYA HALT TRAIN STOP'],
#  (22.82608, 88.16423): ['NALJKUL TRAIN STOP'],
#  (22.141756, 87.200834): ['SINGPUR TRAIN STOP'],
#  (22.801519, 88.281647): ['NASIBPUR TRAIN STOP'],
#  (22.773809, 88.257652): ['DIARA TRAIN STOP'],
#  (23.24785, 88.435): ['SHANTIPUR JN TRAIN STOP'],
#  (23.25092, 88.47122): ['BATHNA KRITTIBAS TRAIN STOP'],
#  (23.229799, 88.497002): ['PHULIA TRAIN STOP'],
#  (23.169767, 88.515976): ['HABIBPUR TRAIN STOP'],
#  (23.207549, 88.573793): ['KALINARAYANPUR JN TRAIN STOP'],
#  (23.23608, 88.55367): ['RANAGHAT JN TRAIN STOP'],
#  (23.361851, 88.65934): ['PAYRADANGA TRAIN STOP'],
#  (23.047857, 88.513016): ['CHAKDAHA TRAIN STOP'],
#  (23.059186, 88.520462): ['PALPARA TRAIN STOP'],
#  (23.03475, 88.505692): ['SIMURALI TRAIN STOP'],
#  (23.008944, 88.491241): ['MADANPUR TRAIN STOP'],
#  (22.98444, 88.404617): ['KALYANI SIMANTA TRAIN STOP'],
#  (22.98311, 88.439857): ['KALYANI GHOSHPARA TRAIN STOP'],
#  (22.97764, 88.4515): ['KALYANI SILPANCHAL TRAIN STOP'],
#  (22.975084, 88.434509): ['KALYANI TRAIN STOP',
#   '10 NO. MAJHIPARA BUS STOP',
#   '10 NO. MAJHIPARA AUTO STOP'],
#  (22.944101, 88.433502): ['KANCHRAPARA TRAIN STOP'],
#  (22.899879, 88.418571): ['HALISHAHAR TRAIN STOP'],
#  (22.847219, 88.42379): ['KANKINARA TRAIN STOP'],
#  (22.864651, 88.392616): ['JAGADDAL TRAIN STOP'],
#  (22.828809, 88.380469): ['SHYAMNAGAR TRAIN STOP'],
#  (22.800613, 88.373669): ['ICHCHHAPUR TRAIN STOP'],
#  (22.781779, 88.36992): ['PALTA TRAIN STOP'],
#  (22.9662, 88.389359): ['BARRACKPORE TRAIN STOP'],
#  (22.74666, 88.373489): ['TITAGARH TRAIN STOP'],
#  (22.72517, 88.377477): ['KHARDAHA TRAIN STOP'],
#  (22.700529, 88.375702): ['SODEPUR TRAIN STOP'],
#  (22.688021, 88.376221): ['AGARPARA TRAIN STOP'],
#  (22.495643, 88.374725): ['BELGHORIA TRAIN STOP'],
#  (22.52975, 88.26942): ['BIDHANNAGAR ROAD TRAIN STOP'],
#  (22.567646, 88.370743): ['SEALDAH TRAIN STOP',
#   'SEALDAH BUS STOP',
#   'SEALDAH AUTO STOP'],
#  (22.540791, 88.369179): ['PARK CIRCUS TRAIN STOP'],
#  (22.5196546, 88.372135): ['BALLYGUNGE JN TRAIN STOP'],
#  (22.510571, 88.376892): ['DHAKURIA TRAIN STOP'],
#  (22.495564, 88.374736): ['JADAVPUR TRAIN STOP'],
#  (22.483017, 88.386651): ['BAGHA JATIN TRAIN STOP'],
#  (22.466465, 88.404978): ['GARIA TRAIN STOP'],
#  (22.468138, 88.413837): ['NARENDRAPUR TRAIN STOP'],
#  (22.41014, 88.43851): ['SONARPUR JN TRAIN STOP'],
#  (22.41581, 88.428833): ['SUBHASGRAM TRAIN STOP'],
#  (22.397307, 88.433186): ['MALLIKPUR TRAIN STOP'],
#  (22.40248, 88.4684): ['BARUIPUR JN TRAIN STOP'],
#  (22.38036, 88.37702): ['SHASAN ROAD TRAIN STOP'],
#  (22.60474, 88.38522): ['KRISHNAMOHAN TRAIN STOP'],
#  (22.346239, 88.444572): ['DHAPDHAPI TRAIN STOP'],
#  (22.293391, 88.466593): ['SURJYAPUR TRAIN STOP'],
#  (22.280112, 88.45399): ['GOCHARAN TRAIN STOP'],
#  (22.260351, 88.45046): ['HOGLA HALT TRAIN STOP'],
#  (22.796089, 88.62957): ['DAKSHIN BARASAT TRAIN STOP'],
#  (22.204903, 88.444041): ['BAHARU TRAIN STOP'],
#  (22.169453, 88.415977): ['JAYNAGAR MAJILPUR TRAIN STOP'],
#  (22.120268, 88.394325): ['MATHURAPUR TRAIN STOP'],
#  (22.120534, 88.349134): ['MADHABPUR TRAIN STOP'],
#  (22.110328, 88.322082): ['LAKSHMIKANTAPUR TRAIN STOP'],
#  (22.70607, 88.47303): ['UDAYRAMPUR TRAIN STOP'],
#  (22.076785, 88.255594): ['KULPI TRAIN STOP'],
#  (21.974013, 88.213995): ['NISHCHINDRAPUR TRAIN STOP'],
#  (22.089784, 88.424727): ['KASHINAGAR TRAIN STOP'],
#  (21.87075, 88.185127): ['KAKDWIP TRAIN STOP'],
#  (22.193051, 88.191171): ['DIAMOND HARBOUR TRAIN STOP'],
#  (22.199806, 88.215669): ['GURUDAS NAGAR TRAIN STOP'],
#  (22.20402, 88.229919): ['BASULDANGA TRAIN STOP'],
#  (22.208924, 88.255471): ['NETRA TRAIN STOP'],
#  (22.214653, 88.280492): ['DEULA TRAIN STOP'],
#  (22.225758, 88.329616): ['SANGRAMPUR TRAIN STOP'],
#  (22.230244, 88.349728): ['BAHIRPUYA HALT TRAIN STOP'],
#  (22.241675, 88.372752): ['MAGRA HAT TRAIN STOP'],
#  (22.26517, 88.3854): ['UTTAR RADHANAGAR HALT TRAIN STOP'],
#  (22.290045, 88.39186): ['DHAMUAH TRAIN STOP'],
#  (22.308878, 88.399303): ['HOTAR TRAIN STOP'],
#  (22.325257, 88.405879): ['DAKSHIN DURGAPUR TRAIN STOP'],
#  (22.343741, 88.41501): ['KALYANPUR TRAIN STOP'],
#  (22.313958, 88.668059): ['CANNING TRAIN STOP'],
#  (22.343681, 88.609005): ['TALDI TRAIN STOP'],
#  (22.351073, 88.574547): ['BETBERIA GHOLA HALT TRAIN STOP'],
#  (22.368332, 88.552673): ['GHUTIARI SHARIFF TRAIN STOP'],
#  (22.388342, 88.517601): ['PIALI TRAIN STOP'],
#  (22.35668, 88.464447): ['CHAMPAHATI TRAIN STOP'],
#  (22.41216682, 88.47571744): ['KALIKAPUR TRAIN STOP'],
#  (22.425399, 88.452998): ['BIDHYADHARPUR TRAIN STOP'],
#  (22.47296, 88.173248): ['BUDGE BUDGE TRAIN STOP',
#   'CHARIAL MORE BUS STOP',
#   'CHARIAL MORE AUTO STOP'],
#  (22.50767, 88.22102): ['NANGI TRAIN STOP'],
#  (22.514795, 88.249125): ['AKRA TRAIN STOP',
#   'AKRA STATION BUS STOP',
#   'AKRA STATION AUTO STOP'],
#  (22.52418043, 88.27167498): ['SANTOSHPUR TRAIN STOP'],
#  (22.523729, 88.305168): ['BRACE BRIDGE TRAIN STOP'],
#  (22.52355, 88.31869): ['MAJHERHAT TRAIN STOP'],
#  (22.507933, 88.347364): ['TOLLYGUNGE TRAIN STOP'],
#  (22.508309, 88.353348): ['LAKE GARDENS TRAIN STOP'],
#  (23.388625, 88.493745): ['KRISHNANAGAR CITY JN TRAIN STOP'],
#  (23.347218, 88.514147): ['JALALKHALI HALT TRAIN STOP'],
#  (23.303611, 88.528682): ['BADKULLA TRAIN STOP'],
#  (23.258916, 88.537308): ['TAHERPUR TRAIN STOP'],
#  (23.236851, 88.552803): ['BIRNAGAR TRAIN STOP'],
#  (23.492413, 88.787382): ['GEDE TRAIN STOP'],
#  (23.47019, 88.778135): ['HARISHNAGAR TRAIN STOP'],
#  (23.455006, 88.754172): ['BANPUR TRAIN STOP'],
#  (23.42557, 88.722588): ['MAJHDIA TRAIN STOP'],
#  (23.380321, 88.680452): ['TARAKNAGAR TRAIN STOP'],
#  (23.35804, 88.66482): ['MAYURHAT TRAIN STOP'],
#  (23.31141, 88.641282): ['BHAYNA TRAIN STOP'],
#  (23.4872, 88.59786): ['BAHIRGACHHI TRAIN STOP'],
#  (23.241489, 88.612732): ['ARANGHATA TRAIN STOP'],
#  (23.221395, 88.599808): ['PANCHHEBERIA TRAIN STOP'],
#  (23.20913, 88.591509): ['BANKIMNAGAR  TRAIN STOP'],
#  (23.148609, 88.604347): ['NABA RAYNAGAR HALT TRAIN STOP'],
#  (23.134294, 88.640793): ['GANGNAPUR TRAIN STOP'],
#  (23.625891, 88.282608): ['MAJHERGRAM TRAIN STOP'],
#  (23.095427, 88.717215): ['AKAIPUR HALT TRAIN STOP'],
#  (23.062988, 88.745461): ['GOPALNAGAR TRAIN STOP'],
#  (22.65218, 88.33643): ['SATBERIA HALT TRAIN STOP'],
#  (23.030489, 88.833004): ['BONGAON JN TRAIN STOP'],
#  (23.18947, 88.76934): ['BIBHUTI BHUSHAN HALT TRAIN STOP'],
#  (22.962562, 88.785215): ['CHANDPARA TRAIN STOP'],
#  (22.924887, 88.77779): ['THAKURNAGAR TRAIN STOP'],
#  (22.8801, 88.760902): ['GOBARDANGA TRAIN STOP'],
#  (22.856693, 88.744878): ['MACHLANDAPUR TRAIN STOP'],
#  (22.846152, 88.704519): ['SANHATI HALT TRAIN STOP'],
#  (22.581511, 88.338219): ['HABRA TRAIN STOP'],
#  (22.826831, 88.628586): ['ASHOKNAGAR ROAD TRAIN STOP'],
#  (22.808607, 88.600654): ['GUMA TRAIN STOP',
#   'GUMA BUS STOP',
#   'GUMA AUTO STOP'],
#  (22.790021, 88.572294): ['BIRA TRAIN STOP'],
#  (22.768386, 88.53941): ['DUTTAPUKUR TRAIN STOP'],
#  (22.749502, 88.509763): ['BAMANGACHI TRAIN STOP'],
#  (22.723852, 88.483206): ['BARASAT JN TRAIN STOP'],
#  (22.710895, 88.46967): ['HRIDAYPUR TRAIN STOP',
#   'HRIDAYPUR BUS STOP',
#   'HRIDAYPUR AUTO STOP'],
#  (22.69438, 88.454979): ['MADHYAMGRAM TRAIN STOP'],
#  (22.75399, 88.36953): ['NEW BARRAKPORE TRAIN STOP'],
#  (22.67886, 88.43608): ['BISHARPARA KODALIA TRAIN STOP'],
#  (22.653259, 88.431091): ['BIRATI TRAIN STOP',
#   'MALANCHA BUS STOP',
#   'MALANCHA AUTO STOP'],
#  (21.78583, 88.250648): ['DURGANAGAR TRAIN STOP'],
#  (22.61517, 88.41151): ['DUM DUM CANTT TRAIN STOP'],
#  (22.60845, 88.398201): ['PATIPUKUR TRAIN STOP'],
#  (22.58956, 88.39271): ['ULTADANGA ROAD TRAIN STOP',
#   'HUDCO BUS STOP',
#   'HUDCO AUTO STOP'],
#  (22.607216, 88.377774): ['TALA TRAIN STOP'],
#  (22.603901, 88.367661): ['BAGBAZAR TRAIN STOP'],
#  (22.59748, 88.3601): ['SOVABAZAR AHIRITOLA TRAIN STOP',
#   'SOVABAZAR BUS STOP',
#   'SOVABAZAR AUTO STOP'],
#  (22.581991, 88.354172): ['BURRABAZAR TRAIN STOP'],
#  (22.571751, 88.350349): ['BBD BAG TRAIN STOP'],
#  (22.56649, 88.341179): ['EDEN GARDENS TRAIN STOP'],
#  (22.557241, 88.331614): ['PRINCEP GHAT TRAIN STOP'],
#  (22.57131, 88.913208): ['HASANABAD TRAIN STOP'],
#  (22.588079, 88.915858): ['TAKI ROAD TRAIN STOP'],
#  (22.68438, 88.02645): ['NIMDANRI TRAIN STOP'],
#  (22.62058, 88.896645): ['MADHYAMPUR HALT TRAIN STOP'],
#  (22.64599, 88.872147): ['BASIRHAT TRAIN STOP'],
#  (22.654881, 88.855538): ['BHYABLA HALT TRAIN STOP',
#   'BHABLA STATION BUS STOP',
#   'BHYABLA HALT BUS STOP',
#   'BHABLA STATION AUTO STOP',
#   'BHYABLA HALT AUTO STOP'],
#  (22.61165, 88.796463): ['CHAMPAPUKUR TRAIN STOP'],
#  (22.652188, 88.782976): ['GHORARAS CHONA HALT TRAIN STOP',
#   'GHORARAS BELTALA BUS STOP',
#   'GHORARAS BELTALA AUTO STOP'],
#  (22.652071, 88.762705): ['MALATIPUR FLAG TRAIN STOP'],
#  (22.658631, 88.72172): ['KANKRA MIRZANAGAR HALT TRAIN STOP'],
#  (22.66229, 88.69018): ['HARUA ROAD TRAIN STOP'],
#  (22.66594, 88.658355): ['BHASILA FLAG TRAIN STOP'],
#  (22.673531, 88.640841): ['LABUTALA HALT TRAIN STOP'],
#  (22.703899, 88.604708): ['BELIAGHATA ROAD HALT TRAIN STOP'],
#  (22.682011, 88.582591): ['SONDALIA TRAIN STOP'],
#  (22.686353, 88.564324): ['BAHIRA KALIBARI HALT TRAIN STOP'],
#  (22.704999, 88.534861): ['KAREA KADAMGACHI TRAIN STOP'],
#  (22.47, 88.39): ['Kavi Subhas Metro'],
#  (22.46, 88.39): ['shahid khudiram Metro'],
#  (22.4642, 88.3807): ['kaji najrul Metro'],
#  (22.4695, 88.3714): ['Gitanjali Metro'],
#  (22.4735, 88.3608): ['Masterda Surya Sen Metro'],
#  (22.4809, 88.346): ['Netaji Metro'],
#  (22.4945, 88.3452): ['mahanayak uttam kumar Metro'],
#  (22.5079, 88.3455): ['rabindra sarobar Metro'],
#  (22.5167, 88.346): ['kalighat Metro',
#   'RASHBEHARI BUS STOP',
#   'KALIGHAT BUS STOP',
#   'RASHBEHARI AUTO STOP',
#   'KALIGHAT AUTO STOP'],
#  (22.5243, 88.3465): ['jatin das park Metro',
#   'HAZRA BUS STOP',
#   'HAZRA AUTO STOP'],
#  (22.533, 88.3457): ['netaji bhavan Metro'],
#  (22.5412, 88.3473): ['rabindra sadan Metro',
#   'RABINDRA SADAN BUS STOP',
#   'EXIDE BUS STOP',
#   'RABINDRA SADAN AUTO STOP',
#   'EXIDE AUTO STOP'],
#  (22.5493, 88.3485): ['maidan Metro'],
#  (22.5544, 88.3499): ['park street Metro'],
#  (22.5649, 88.3517): ['esplaned Metro',
#   'SHAMALI BUS STOP',
#   'SHAMALI AUTO STOP'],
#  (22.6587, 88.3538): ['chandni chowk Metro'],
#  (22.5725, 88.3582): ['central  Metro'],
#  (22.5807, 88.3614): ['mahatma gandhi road Metro'],
#  (22.5871, 88.3631): ['girish park Metro',
#   'GIRISH PARK / COLLEGE STREET BUS STOP',
#   'GIRISH PARK / COLLEGE STREET AUTO STOP'],
#  (22.596, 88.3653): ['shobhabazar sutanuti Metro'],
#  (22.5984, 88.3687): ['Shyambazar Metro'],
#  (22.6039, 88.3844): ['Belgachhia Metro'],
#  (22.642, 88.4132): ['DumDum Metro'],
#  (22.736, 88.4822): ['Noapara Metro'],
#  (22.6427, 88.3777): ['BaranagarMetro'],
#  (22.6573, 88.3624): ['Dakhineswar Metro'],
#  (22.5735, 88.4331): ['Salt Lake sector V Metro'],
#  (22.5863, 88.4214): ['Karunamoyee Metro',
#   'KARUNAMOYEE BUS STOP',
#   'KARUNAMOYEE AUTO STOP'],
#  (22.5868, 88.4149): ['Central Park Metro'],
#  (22.5881, 88.4082): ['City Center  Metro'],
#  (22.58, 88.4013): ['Bengal Chemical Metro',
#   'BENGAL CHEMICAL BUS STOP',
#   'BENGAL CHEMICAL AUTO STOP'],
#  (22.5691, 88.409): ['Solt lake stedium Metro',
#   'SALTLAKE STADIUM BUS STOP',
#   'SALTLAKE STADIUM AUTO STOP'],
#  (22.572, 88.3968): ['Phoolbagan Metro'],
#  (22.566, 88.372): ['Sealdah  Metro'],
#  (22.4533, 88.3025): ['Joka Metro',
#   'JOKA BRIDGE BUS STOP',
#   'JOKA BRIDGE AUTO STOP'],
#  (22.4635, 88.3073): ['Thakurpukur Metro'],
#  (22.4748, 88.3099): ['Sakherbazar Metro'],
#  (22.4867, 88.3136): ['Behala Chowrasta Metro'],
#  (22.5004, 88.3173): ['Behala Bazar Metro'],
#  (22.5169, 88.2991): ['Taratala Metro'],
#  (23.6931, 88.318964): ['BNR BUS STOP', 'BNR AUTO STOP'],
#  (22.542061, 88.318954): ['KIDDERPORE BUS STOP', 'KIDDERPORE AUTO STOP'],
#  (22.54589, 88.318964): ['BHABANI BHAWAN BUS STOP',
#   'BHABANI BHAWAN AUTO STOP'],
#  (22.5367, 88.3334): ['ALIPORE ZOO BUS STOP', 'ALIPORE ZOO AUTO STOP'],
#  (22.5197, 88.3652): ['GARIAHAT BUS STOP', 'GARIAHAT AUTO STOP'],
#  (22.5188, 88.375): ['KASBA POST OFFICE BUS STOP',
#   'KASBA POST OFFICE AUTO STOP'],
#  (22.500914, 88.394936): ['HALTU BUS STOP', 'HALTU AUTO STOP'],
#  (22.6396737, 88.3300048): ['SAFUIPARA BUS STOP', 'SAFUIPARA AUTO STOP'],
#  (22.561594, 88.408495): ['EM BYPASS BUS STOP',
#   'EM BYPASS AUTO STOP',
#   'BHABANI BHAWAN HAZRA AUTO STOP',
#   'BELEGHATA CIT MORE AUTO STOP',
#   'BELIAGHATA BRIDGE AUTO STOP'],
#  (22.561694, 88.408495): ['BHABANI BHAWAN HAZRA BUS STOP',
#   'EM BYPASS AUTO STOP',
#   'BHABANI BHAWAN HAZRA AUTO STOP',
#   'BELEGHATA CIT MORE AUTO STOP',
#   'BELIAGHATA BRIDGE AUTO STOP'],
#  (22.4986357, 88.3453906): ['TOLLYGUNGE PHARI BUS STOP',
#   'TOLLYGUNGE PHARI AUTO STOP'],
#  (22.4961, 88.3706): ['JADAVPUR PS BUS STOP',
#   'JADAVPUR PS AUTO STOP',
#   '8B AUTO STOP',
#   'JADAVPUR 8B AUTO STOP'],
#  (22.4957, 88.3707): ['JADAVPUR 8B BUS STOP',
#   'JADAVPUR PS AUTO STOP',
#   '8B AUTO STOP',
#   'JADAVPUR 8B AUTO STOP'],
#  (22.776, 88.5002): ['SANTOSHPUR BUS STOP', 'SANTOSHPUR AUTO STOP'],
#  (22.4895, 88.3954): ['NATURE PARK BUS STOP',
#   'AJOYNAGAR AUTO STOP',
#   'NATURE PARK AUTO STOP',
#   'AJAYNAGAR AUTO STOP'],
#  (22.5173, 88.298): ['TARATALA BUS STOP', 'TARATALA AUTO STOP'],
#  (22.5186, 88.3535): ['DESHAPRIYA PARK BUS STOP',
#   'DESAPRIYA PARK AUTO STOP',
#   'DESHAPRIYA PARK AUTO STOP'],
#  (22.515868, 88.365136): ['GOLPARK BUS STOP', 'GOLPARK AUTO STOP'],
#  (22.5094, 88.3676): ['DHAKURIA BUS STOP', 'DHAKURIA AUTO STOP'],
#  (22.4726, 88.3981): ['EM BYPASS NEW GARIA BUS STOP',
#   'EM BYPASS NEW GARIA AUTO STOP'],
#  (22.4681, 88.4039): ['GARIA STATION BUS STOP',
#   'GARIA STATION AUTO STOP',
#   'GARIA BUS STAND AUTO STOP'],
#  (23.53344, 87.32193): ['DURGAPUR BRIDGE BUS STOP',
#   'DURGAPUR BRIDGE AUTO STOP'],
#  (22.5376, 88.3526): ['BHOWANIPORE BUS STOP',
#   'BHAWANIPUR AUTO STOP',
#   'BHOWANIPORE AUTO STOP',
#   'SREEPALLY AUTO STOP'],
#  (22.554443, 88.340569): ['MAIDAN METRO BUS STOP',
#   'MAIDAN AUTO STOP',
#   'MAIDAN METRO AUTO STOP'],
#  (22.57687, 88.35047): ['PARK STREET BUS STOP', 'PARK STREET AUTO STOP'],
#  (22.5631, 88.3507): ['BABUGHAT / ESPLANADE BUS STOP',
#   'ESPLANADE AUTO STOP',
#   'BABUGHAT / ESPLANADE AUTO STOP'],
#  (22.568217, 88.356643): ['CHANDNI CHOWK BUS STOP', 'CHANDNI CHOWK AUTO STOP'],
#  (22.5787, 88.3608): ['CENTRAL BUS STOP',
#   'CENTRAL AUTO STOP',
#   'M.G. ROAD AUTO STOP'],
#  (22.598038, 88.377494): ['MEDICAL COLLEGE BUS STOP',
#   'MEDICAL COLLEGE AUTO STOP'],
#  (22.665815, 88.39022): ['M.G.ROAD BUS STOP',
#   'MG ROAD METRO AUTO STOP',
#   'M.G.ROAD AUTO STOP'],
#  (22.5862, 88.3637): ['GIRISH PARK BUS STOP', 'GIRISH PARK AUTO STOP'],
#  (22.5853, 88.3752): ['MANIKTALA BUS STOP',
#   'SHOBHABAZAR AUTO STOP',
#   'MANIKTALA AUTO STOP',
#   ' MANIKTALA AUTO STOP'],
#  (22.601983, 88.3731): ['SHYAMBAZAR 5 POINT BUS STOP',
#   'SHYAMBAZAR 5 POINT AUTO STOP',
#   'COLLEGE STREET AUTO STOP'],
#  (22.6046, 88.3783): ['RG KAR BUS STOP', 'RG KAR AUTO STOP'],
#  (22.6058, 88.3866): ['BELGACHIA METRO BUS STOP', 'BELGACHIA METRO AUTO STOP'],
#  (22.515, 88.4012): ['RUBY HOSPITAL BUS STOP',
#   'RUBY AUTO STOP',
#   'RUBY HOSPITAL AUTO STOP'],
#  (22.517618, 88.384048): ['KASBA PS BUS STOP',
#   'KASBA AUTO STOP',
#   'KASBA PS AUTO STOP',
#   'BOSEPUKUR AUTO STOP'],
#  (22.5816, 88.3848): ['RAJABAZAR BUS STOP',
#   'BALLYGUNGE STATION AUTO STOP',
#   'RAJABAZAR AUTO STOP'],
#  (22.5325, 88.3764): ['NOUL BAZAR BUS STOP',
#   'WELLINGTON AUTO STOP',
#   'KHANNA AUTO STOP',
#   'HASTINGS AUTO STOP',
#   'GOAKHALI MORE AUTO STOP',
#   'KUSTIA MORE AUTO STOP',
#   'NEPALGUNGE AUTO STOP',
#   'BAKESHWAR AUTO STOP',
#   'MALLICKPUR AUTO STOP',
#   'SAJNABERIA AUTO STOP',
#   'KAMAL TALKIES AUTO STOP',
#   'LANSDOWNE AUTO STOP',
#   'NARAYANA HOSPITAL AUTO STOP',
#   'KATLIA MORE AUTO STOP',
#   'JAPANI GATE AUTO STOP',
#   'KAMINA MORE AUTO STOP',
#   'KHALORE MORE AUTO STOP',
#   'BANTUL MORE AUTO STOP',
#   'NUNTIA MORE AUTO STOP',
#   'NOUL BAZAR AUTO STOP'],
#  (22.5611, 88.366): ['MOULALI BUS STOP',
#   'MOULALI AUTO STOP',
#   'SEALDAH STATION MOULALI MORE AUTO STOP'],
#  (22.6027, 88.4121): ['BANGUR AVENUE BUS STOP', 'BANGUR AVENUE AUTO STOP'],
#  (22.614866, 88.41269): ['DIAMOND PLAZA BUS STOP', 'DIAMOND PLAZA AUTO STOP'],
#  (22.5232, 88.352): ['SHISHU MANGAL BUS STOP',
#   'SHISHU MANGAL AUTO STOP',
#   'SISHU MANGAL AUTO STOP',
#   'SHISHUMANGAL HOSPITAL AUTO STOP'],
#  (22.5414, 88.3544): ['MINTO PARK BUS STOP', 'MINTO PARK AUTO STOP'],
#  (22.6013, 88.3735): ['COLLEGE STREET BUS STOP',
#   'SHYAMBAZAR 5 POINT AUTO STOP',
#   'COLLEGE STREET AUTO STOP'],
#  (22.5946, 88.3709): ['HATIBAGAN BUS STOP', 'HATIBAGAN AUTO STOP'],
#  (22.5023, 88.3184): ['BEHALA 14NO BUS STOP',
#   'BEHALA 14 NO. AUTO STOP',
#   'BEHALA 14NO. AUTO STOP',
#   'BHASHA 14NO. AUTO STOP',
#   'BEHALA 14NO AUTO STOP'],
#  (22.5299, 88.3145): ['MOMINPORE BUS STOP', 'MOMINPORE AUTO STOP'],
#  (22.594044, 88.385956): ['WIPRO MORE BUS STOP',
#   'EKBALPUR AUTO STOP',
#   'SUSHRUT HOSPITAL AUTO STOP',
#   'WIPRO MORE AUTO STOP'],
#  (22.543571, 88.267934): ['METIABRUZ BUS STOP', 'METIABRUZ AUTO STOP'],
#  (22.5652, 88.267934): ['RAMNAGAR BUS STOP', 'RAMNAGAR AUTO STOP'],
#  (22.5652, 88.3396): ['H.M.G. COLLEGE BUS STOP',
#   'BABUGHAT AUTO STOP',
#   'H.M.G. COLLEGE AUTO STOP'],
#  (22.567415, 88.392433): ['SARKARPOOL BUS STOP',
#   'BICHALIGHAT AUTO STOP',
#   'FATEHPUR AUTO STOP',
#   'SARKARPOOL AUTO STOP'],
#  (22.5435, 88.3396): ['FATEHPUR 28 NO BUS STOP', 'FATEHPUR 28 NO AUTO STOP'],
#  (22.5435, 88.2862): ['RAJABAGAN BUS STOP', 'RAJABAGAN AUTO STOP'],
#  (22.572645, 88.3396): ['BICHALI GHAR BUS STOP', 'BICHALI GHAR AUTO STOP'],
#  (22.572645, 88.363892): ['MUDIALI MORE BUS STOP', 'MUDIALI MORE AUTO STOP'],
#  (22.5553, 88.3312): ['PRINCEP GHAT BUS STOP',
#   'GARDEN REACH AUTO STOP',
#   'PRINCEP GHAT AUTO STOP'],
#  (22.572645, 88.392433): ['BABUBAZAR BUS STOP', 'BABUBAZAR AUTO STOP'],
#  (23.0285, 88.3711): ['BARABAZAR BUS STOP', 'BARABAZAR AUTO STOP'],
#  (22.487022, 88.387131): ['SANTOSHPUR STATION BUS STOP',
#   'SANTOSHPUR STATION AUTO STOP'],
#  (23.0285, 88.3492): ['MAJHERHAT BUS STOP',
#   'JHINJHIRA BAZAR AUTO STOP',
#   'MAJHERHAT AUTO STOP'],
#  (22.5256, 88.30019): ['BRACE BRIDGE BUS STOP', 'BRACE BRIDGE AUTO STOP'],
#  (22.57285, 88.3492): ['FORT WILLIAM BUS STOP', 'FORT WILLIAM AUTO STOP'],
#  (22.5707, 88.3495): ['DALHOUSIE BUS STOP', 'DALHOUSIE AUTO STOP'],
#  (22.4568, 88.3045): ['THAKURPUKUR 3A BUS STOP',
#   'THAKURPUKUR AUTO STOP',
#   'THAKURPUKUR 3A AUTO STOP'],
#  (22.474739, 88.311174): ['SHILPARA BUS STOP', 'SHILPARA AUTO STOP'],
#  (22.4568, 88.3184): ['SAKHER BAZAR BUS STOP', 'SAKHER BAZAR AUTO STOP'],
#  (22.41894, 88.310837): ['BEHALA CHOWRASTA BUS STOP',
#   'BEHALA CHOWRASTA AUTO STOP'],
#  (22.528887, 88.306836): ['HIDE ROAD BUS STOP', 'HIDE ROAD AUTO STOP'],
#  (22.5459, 88.312): ['B.N.R. HOSPITAL BUS STOP', 'B.N.R. HOSPITAL AUTO STOP'],
#  (22.4834, 88.2881): ['SHAKUNTALA PARK BUS STOP', 'SHAKUNTALA PARK AUTO STOP'],
#  (22.57791, 88.32873): ['BAKULTALA BUS STOP', 'BAKULTALA AUTO STOP'],
#  (22.5681, 88.4577): ['THAKDARI BUS STOP', 'THAKDARI AUTO STOP'],
#  (22.598841, 88.431907): ['KESTOPUR BAZAR BUS STOP',
#   'KESTOPUR BAZAR AUTO STOP'],
#  (22.6032, 88.4193): ['DUMDUM PARK BUS STOP', 'DUMDUM PARK AUTO STOP'],
#  (22.6049, 88.40365): ['LAKETOWN BUS STOP', 'LAKETOWN AUTO STOP'],
#  (22.596166, 88.400368): ['SREEBHUMI BUS STOP',
#   'SREEBHUMI AUTO STOP',
#   'GHUSHIGHATA AUTO STOP'],
#  (22.5944, 88.3919): ['ULTADANGA BUS STOP',
#   'ULTADANGA AUTO STOP',
#   'ULTODANGA AUTO STOP'],
#  (22.59444, 88.3752734): ['KHANNA CINEMA BUS STOP', 'KHANNA CINEMA AUTO STOP'],
#  (22.5654, 88.3701): ['SEALDAH STATION BUS STOP',
#   'SEALDAH STATION AUTO STOP',
#   'SEALDAH COURT AUTO STOP'],
#  (22.569725, 88.360899): ['CENTRAL METRO BUS STOP',
#   'BOWBAZAR AUTO STOP',
#   'CENTRAL METRO AUTO STOP'],
#  (23.9201, 88.360899): ['OKA BRIDGE BUS STOP', 'OKA BRIDGE AUTO STOP'],
#  (22.4591, 88.3197): ['CANCER HOSPITAL BUS STOP', 'CANCER HOSPITAL AUTO STOP'],
#  (23.9201, 87.9939): ['KALITALA HOUSING BUS STOP',
#   'KALITALA HOUSING AUTO STOP'],
#  (22.4634, 88.3334): ['KABARDANGA BUS STOP', 'KABARDANGA AUTO STOP'],
#  (22.700346, 88.374535): ['KEORAPUKUR BUS STOP',
#   'KEORAPUKUR AUTO STOP',
#   'SODPUR TRAFFIC MORE AUTO STOP'],
#  (22.48, 88.3379): ['HARIDEVPUR BUS STOP', 'HARIDEVPUR AUTO STOP'],
#  (22.4874, 88.3423): ['TOLLYGUNGE BUS STOP', 'TOLLYGUNGE AUTO STOP'],
#  (22.511, 88.3561): ['RABINDRA SAROVAR BUS STOP',
#   'RABINDRA SAROVAR AUTO STOP'],
#  (22.087, 88.1373): ['HAZRA MORE BUS STOP', 'HAZRA MORE AUTO STOP'],
#  (22.52505, 88.331124): ['ALIPORE COURT BUS STOP', 'ALIPORE COURT AUTO STOP'],
#  (22.511976, 88.250992): ['MOLLARGATE BUS STOP', 'MOLLARGATE AUTO STOP'],
#  (22.515, 88.2825): ['RAMPUR QUARTER BUS STOP', 'RAMPUR QUARTER AUTO STOP'],
#  (22.52505, 88.2825): ['S.M. NAGAR BUS STOP', 'S.M. NAGAR AUTO STOP'],
#  (22.9487, 88.3231): ['SHIBRAMPUR BUS STOP', 'SHIBRAMPUR AUTO STOP'],
#  (23.538631, 88.3535): ['MOYNAGARH BUS STOP', 'MOYNAGARH AUTO STOP'],
#  (22.4909, 88.3255): ['SARADA PARK BUS STOP', 'SARADA PARK AUTO STOP'],
#  (22.517943, 88.383398): ['BOSEPUKUR BUS STOP',
#   'KASBA AUTO STOP',
#   'KASBA PS AUTO STOP',
#   'BOSEPUKUR AUTO STOP'],
#  (22.514807, 88.393166): ['ACROPOLIS MALL BUS STOP',
#   'ACROPOLIS MALL AUTO STOP'],
#  (22.4803, 88.2946): ['SARSUNA BUS STOP', 'SARSUNA AUTO STOP'],
#  (22.4803, 88.3403): ['M.L.GUPTA ROAD BUS STOP', 'M.L.GUPTA ROAD AUTO STOP'],
#  (22.4871, 88.3321): ['MUCHIPARA BUS STOP', 'MUCHIPARA AUTO STOP'],
#  (22.4895, 88.3385): ['SIRITI MORE BUS STOP', 'SIRITI MORE AUTO STOP'],
#  (22.5015, 88.3403): ['N.S.H.M. CAMPUS BUS STOP', 'N.S.H.M. CAMPUS AUTO STOP'],
#  (22.5015, 88.358344): ['MAHABIRTALA BUS STOP', 'MAHABIRTALA AUTO STOP'],
#  (22.539878, 88.358344): ['BECKBAGAN BUS STOP', 'BECKBAGAN AUTO STOP'],
#  (22.548704, 88.359679): ['MALLICK BAZAR BUS STOP', 'MALLICK BAZAR AUTO STOP'],
#  (22.33, 88.22): ['MOULALI MORE BUS STOP', 'MOULALI MORE AUTO STOP'],
#  (22.509, 88.3348): ['NEW ALIPORE BUS STOP', 'NEW ALIPORE AUTO STOP'],
#  (22.7201, 88.4861): ['CHAMPADALI MORE BUS STOP',
#   'CHAPADALI MORE AUTO STOP',
#   'BARASAT CHAMPADALI MORE AUTO STOP',
#   'BARASAT CHAMPADALI AUTO STOP',
#   'CHAMPADALI MORE AUTO STOP'],
#  (22.7201, 88.4872): ['KAZIPARA DEPOT BUS STOP',
#   'KAZIPARA DEPOT AUTO STOP',
#   'BARASAT CHAMPADALI AUTO STOP'],
#  (22.7201, 88.6987449): ['KADAMBAGACHI BUS STOP', 'KADAMBAGACHI AUTO STOP'],
#  (22.567415, 88.398433): ['GOLABARI MORE BUS STOP', 'GOLABARI MORE AUTO STOP'],
#  (22.55021718, 88.37939144): ['CHRISTOPHER ROAD BUS STOP',
#   'PAKDAHA AUTO STOP',
#   'CHRISTOPHER ROAD AUTO STOP'],
#  (22.54982, 88.382): ['PANCHKARI MORE BUS STOP',
#   'AMINPUR AUTO STOP',
#   'PANCHKARI MORE AUTO STOP'],
#  (23.4558, 88.691): ['TANGRA MORE BUS STOP',
#   'PALTADANGA AUTO STOP',
#   'TANGRA MORE AUTO STOP'],
#  (22.70245, 88.69485): ['SHASAN BAZAR BUS STOP', 'SHASAN BAZAR AUTO STOP'],
#  (23.644367, 88.132858): ['LAKE GARDENS BUS STOP',
#   'MITHPUKURIA AUTO STOP',
#   'SOUTH CITY AUTO STOP',
#   'LAKE GARDENS AUTO STOP'],
#  (22.54982, 88.69485): ['MAJLISHPUR BUS STOP', 'MAJLISHPUR AUTO STOP'],
#  (22.6127, 88.4353): ['R.N.CHOWDHURY ROAD BUS STOP',
#   'R.N.CHOWDHURY ROAD AUTO STOP'],
#  (22.5614, 88.377): ['PALMER BAZAR BUS STOP', 'PALMER BAZAR AUTO STOP'],
#  (22.57857, 88.36076): ['M.G. ROAD BUS STOP',
#   'CENTRAL AUTO STOP',
#   'M.G. ROAD AUTO STOP'],
#  (22.584, 88.343): ['HOWRAH STATION BUS STOP', 'HOWRAH STATION AUTO STOP'],
#  (22.58336, 88.333): ['HOWRAH MAIDAN BUS STOP', 'HOWRAH MAIDAN AUTO STOP'],
#  (22.5944, 88.339): ['PILKHANA MORE BUS STOP', 'PILKHANA MORE AUTO STOP'],
#  (22.601, 88.342): ['SALKIA CHOWRASTA BUS STOP', 'SALKIA CHOWRASTA AUTO STOP'],
#  (22.56544, 88.35467): ['CHANDNI MARKET BUS STOP', 'CHANDNI MARKET AUTO STOP'],
#  (22.503, 88.4): ['KALIKAPUR BUS STOP', 'KALIKAPUR AUTO STOP'],
#  (22.5254, 88.395): ['V.I.P. BAZAR BUS STOP', 'V.I.P. BAZAR AUTO STOP'],
#  (22.541, 88.398): ['SCIENCE CITY BUS STOP', 'SCIENCE CITY AUTO STOP'],
#  (22.541, 88.38744): ['TOPSIA MORE BUS STOP', 'TOPSIA MORE AUTO STOP'],
#  (22.539, 88.37): ['4NO. BRIDGE BUS STOP',
#   '4NO. BRIDGE AUTO STOP',
#   '4 NO BRIDGE AUTO STOP',
#   'GOURHATI MORE AUTO STOP',
#   'MADHYAMGRAM STATION AUTO STOP',
#   'SUSRUT EYE HOSPITAL AUTO STOP'],
#  (22.545, 88.37): ['CHITTARANJAN HOSPITAL BUS STOP',
#   'CHITTARANJAN HOSPITAL AUTO STOP',
#   'SEC V AUTO STOP',
#   'BELIAGHATA AUTO STOP',
#   'BERABERIA AUTO STOP',
#   'KHATURA BAZAR AUTO STOP',
#   'BELEGHATA CIT BUILDING AUTO STOP',
#   'BARUNDA AUTO STOP',
#   'ANANTAPUR AUTO STOP'],
#  (22.5628, 88.3964): ['C.I.T. ROAD BUS STOP',
#   'C.I.T. ROAD AUTO STOP',
#   'CIT MORE AUTO STOP'],
#  (22.61878, 88.37995): ['CHIRIA MORE BUS STOP',
#   'CHIRIA MORE AUTO STOP',
#   'CHIRIAMORE AUTO STOP'],
#  (22.2503, 88.4354): ['SHYAMBAZAR BUS STOP', 'SHYAMBAZAR AUTO STOP'],
#  (22.599, 88.367): ['RAJBALLAVPARA BUS STOP', 'RAJBALLAVPARA AUTO STOP'],
#  (22.65938, 88.4414): ['BIRATI MORE BUS STOP', 'BIRATI MORE AUTO STOP'],
#  (22.653, 88.436): ['AIRPORT 3NO. BUS STOP',
#   'AIRPORT 3NO. AUTO STOP',
#   'AIRPORT 3 NO. GATE AUTO STOP',
#   'AIRPORT GATE-3 AUTO STOP',
#   'AIRPORT GATE AUTO STOP',
#   'VAISHALI AUTO STOP',
#   'FCI GODOWN AUTO STOP',
#   'BELARI MOLLAH MORE AUTO STOP',
#   'GABBERIA CHOTOPOLE AUTO STOP'],
#  (22.643, 88.432): ['AIRPORT 1NO. BUS STOP',
#   'AIRPORT 1NO. AUTO STOP',
#   'AIRPORT AUTO STOP',
#   'AIRPORT 1 NO. GATE AUTO STOP',
#   'HOWRAH COURT AUTO STOP',
#   'DUMURJOLA HOUSING COMPLEX AUTO STOP',
#   'BASTALA AUTO STOP'],
#  (22.629, 88.421): ['CENTRAL JAIL BUS STOP', 'CENTRAL JAIL AUTO STOP'],
#  (22.623, 88.414): ['NAGER BAZAR BUS STOP',
#   'NAGER BAZAR AUTO STOP',
#   'NAGERBAZAR AUTO STOP'],
#  (22.60945, 88.4005): ['KALINDI MORE BUS STOP',
#   'KALINDI MORE AUTO STOP',
#   'KALINDI AUTO STOP',
#   'LAKE TOWN JESSORE ROAD AUTO STOP'],
#  (22.608, 88.3953): ['PATIPUKUR BUS STOP', 'PATIPUKUR AUTO STOP'],
#  (22.605, 88.38409): ['BELGACHIA BUS STOP',
#   'BELGACHIA AUTO STOP',
#   'BELGACHI AUTO STOP'],
#  (22.6031, 88.377): ['R.G.KAR HOSPITAL BUS STOP',
#   'R.G.KAR HOSPITAL AUTO STOP',
#   'RG KAR HOSPITAL AUTO STOP',
#   'R.G KAR HOSPITAL AUTO STOP'],
#  (22.56156, 88.366): ['SEALDAH STATION MOULALI MORE BUS STOP',
#   'MOULALI AUTO STOP',
#   'SEALDAH STATION MOULALI MORE AUTO STOP'],
#  (22.6101, 88.44): ['HELA BATTALA BUS STOP', 'HELA BATTALA AUTO STOP'],
#  (22.6176, 88.4346): ['JYANGRA BUS STOP', 'JYANGRA AUTO STOP'],
#  (22.609, 88.431): ['ASHWINI NAGAR BUS STOP', 'ASHWINI NAGAR AUTO STOP'],
#  (22.609, 88.427): ['BAGUIATI BUS STOP',
#   'BAGUIATI AUTO STOP',
#   'NARAYANTALA AUTO STOP',
#   'BAGULAKHALI AUTO STOP'],
#  (22.603, 88.423): ['KESTOPUR BUS STOP',
#   'KESTOPUR AUTO STOP',
#   'KESHTOPUR AUTO STOP'],
#  (22.65231, 88.377): ['DUNLOP MORE BUS STOP',
#   'DUNLOP MORE AUTO STOP',
#   'DUNLOP BRIDGE AUTO STOP',
#   'DUNLOP AUTO STOP'],
#  (22.6503, 88.3822): ['BONHOOGHLY BUS STOP',
#   'BONHOOGHLY AUTO STOP',
#   'BONHOOGHLY TOBIN ROAD AUTO STOP',
#   'BONHOOGLY AUTO STOP'],
#  (22.637, 88.378): ['TOBIN ROAD BUS STOP', 'TOBIN ROAD AUTO STOP'],
#  (22.631, 88.3786): ['SINTHEE MORE BUS STOP',
#   'SINTHEE MORE AUTO STOP',
#   'SINTHI AUTO STOP',
#   'SINTHEE AUTO STOP',
#   'LANGALPOTA AUTO STOP',
#   'ENTALLY AUTO STOP'],
#  (22.59, 88.399): ['SALTLAKE P.N.B. BUS STOP', 'SALTLAKE P.N.B. AUTO STOP'],
#  (22.59177, 88.4278): ['SALTLAKE C.A. BLOCK BUS STOP',
#   'SALTLAKE C.A. BLOCK AUTO STOP'],
#  (22.5833468, 88.4073503): ['LABONY ESTATE BUS STOP',
#   'LABONY ESTATE AUTO STOP'],
#  (22.574451, 88.409085): ['SALTLAKE 13NO. TANK BUS STOP',
#   'SALTLAKE 13NO. TANK AUTO STOP'],
#  (22.5729, 88.4308): ['SALTLAKE 14NO. TANK BUS STOP',
#   'SALTLAKE 14NO. TANK AUTO STOP'],
#  (22.5689, 88.4308): ['S.D.F MORE BUS STOP',
#   'S.D.F. MORE AUTO STOP',
#   'S.D.F MORE AUTO STOP',
#   'GP BLOCK AUTO STOP',
#   'SDF AUTO STOP',
#   '5 NO. KALIMATH AUTO STOP',
#   'BONCHAKHALI BAZAR AUTO STOP',
#   'BETAI BONDOR MORE AUTO STOP',
#   'AMTA COLLEGE MORE AUTO STOP'],
#  (22.5729, 88.4384): ['KALABERIA BUS STOP',
#   'COLLEGE MORE AUTO STOP',
#   'KALABERIA AUTO STOP',
#   'SECTOR V AUTO STOP',
#   'GODREJ WATERSIDE AUTO STOP'],
#  (22.64132, 88.37727): ['BARANAGAR BAZAR BUS STOP',
#   'BARANAGAR BAZAR AUTO STOP'],
#  (22.5879, 88.3683): ['HEDUA MORE BUS STOP', 'HEDUA MORE AUTO STOP'],
#  (22.58959, 88.431838): ['VIVEKANANDA ROAD BUS STOP',
#   'VIVEKANANDA ROAD AUTO STOP'],
#  (22.56498, 88.35954): ['HIND CINEMA BUS STOP', 'HIND CINEMA AUTO STOP'],
#  (22.501946, 88.356483): ['ANWAR SHAH ROAD BUS STOP',
#   'ANWAR SHAH ROAD AUTO STOP'],
#  (22.723703, 88.381622): ['COLONY BAZAR BUS STOP', 'COLONY BAZAR AUTO STOP'],
#  (23.93, 88.25): ['BONDEL GATE BUS STOP', 'BONDEL GATE AUTO STOP'],
#  (22.549606, 88.357771): ['PARK CIRCUS BUS STOP', 'PARK CIRCUS AUTO STOP'],
#  (22.549606, 88.451271): ['MITTIRCHAK BUS STOP', 'MITTIRCHAK AUTO STOP'],
#  (22.4849967, 88.3664167): ['BIJOYGARH BUS STOP', 'BIJOYGARH AUTO STOP'],
#  (22.484213, 88.354332): ['RANIKUTHI BUS STOP',
#   'GANDHI COLONY AUTO STOP',
#   'RANIKUTHI AUTO STOP'],
#  (22.479591, 88.358629): ['NETAJI NAGAR BUS STOP', 'NETAJI NAGAR AUTO STOP'],
#  (22.508037, 88.513015): ['MALANCHA CINEMA BUS STOP',
#   'MALANCHA CINEMA AUTO STOP'],
#  (22.5281, 88.3658): ['BALLYGUNGE PHARI BUS STOP',
#   'BALLYGUNGE PHARI AUTO STOP'],
#  (22.53505, 88.35941): ['GARCHA ROAD BUS STOP', 'GARCHA ROAD AUTO STOP'],
#  (22.5234, 88.3517): ['SISHU MANGAL BUS STOP',
#   'SHISHU MANGAL AUTO STOP',
#   'SISHU MANGAL AUTO STOP',
#   'SHISHUMANGAL HOSPITAL AUTO STOP'],
#  (22.6481, 88.3633): ['ALAMBAZAR BUS STOP',
#   'ALAMBAZAR AUTO STOP',
#   'ALAMBAZAR MORE AUTO STOP'],
#  (22.5325, 88.4335): ['DESHBANDHU ROAD BUS STOP', 'DESHBANDHU ROAD AUTO STOP'],
#  (22.37, 88.22): ['COSSIPORE BUS STOP', 'COSSIPORE AUTO STOP'],
#  (23.627499, 87.543282): ['BIBIBAZAR BUS STOP', 'BIBIBAZAR AUTO STOP'],
#  (22.3626, 88.221): ['CHITPUR BRIDGE BUS STOP', 'CHITPUR BRIDGE AUTO STOP'],
#  (22.603757, 88.369065): ['BAGBAZAR BUS STOP', 'BAGBAZAR AUTO STOP'],
#  (22.5775, 88.3936): ['KANKURGACHI BUS STOP', 'KANKURGACHI AUTO STOP'],
#  (22.5668, 88.3974): ['PHOOLBAGAN BUS STOP', 'PHOOLBAGAN AUTO STOP'],
#  (22.5655, 88.3838): ['BOLDEGHATA BUS STOP',
#   'BELEGHATA AUTO STOP',
#   'BOLDEGHATA AUTO STOP'],
#  (22.59106798, 88.41688809): ['BIKASH BHAWAN BUS STOP',
#   'BIKASH BHAWAN AUTO STOP',
#   'BIKASH BHABAN AUTO STOP'],
#  (22.5898, 88.4085): ['CITY CENTER 1 BUS STOP', 'CITY CENTER 1 AUTO STOP'],
#  (22.635, 88.437): ['KAIKHALI BUS STOP', 'KAIKHALI AUTO STOP'],
#  (22.6276, 88.4331): ['HALDIRAMS BUS STOP',
#   'HALDIRAMS AUTO STOP',
#   'HALDIRAM AUTO STOP'],
#  (22.5388, 88.3653): ['QUEST MALL BUS STOP', 'QUEST MALL AUTO STOP'],
#  (22.4835, 88.3754): ['BAGHAJATIN BUS STOP',
#   'BAGHAJATIN AUTO STOP',
#   'KARIGARI BHAVAN AUTO STOP',
#   'SODEPUR AUTO STOP',
#   'HARIPARA AUTO STOP',
#   'SHAORABERIA AUTO STOP',
#   'JAYANTI AUTO STOP',
#   'AIRPORT 2 NO GATE AUTO STOP',
#   'ULUBERIA STATION AUTO STOP',
#   'AXIS MALL / HOMETOWN AUTO STOP'],
#  (23.6214, 88.3754): ['RAMGARH BUS STOP', 'RAMGARH AUTO STOP'],
#  (22.4724, 88.3909): ['GARIA METRO BUS STOP', 'GARIA METRO AUTO STOP'],
#  (22.46506, 88.39142): ['DHALAI BRIDGE BUS STOP', 'DHALAI BRIDGE AUTO STOP'],
#  (22.4703, 88.3883): ['BAISNABGHATA BUS STOP', 'BAISNABGHATA AUTO STOP'],
#  (22.4717451, 88.3896929): ['PATULI MORE BUS STOP', 'PATULI MORE AUTO STOP'],
#  (22.618, 88.464): ['AKANKHA MORE BUS STOP',
#   'AKANKHA MORE AUTO STOP',
#   'AKANKSHA MORE AUTO STOP',
#   'POST OFFICE AUTO STOP',
#   'KALINAGAR MORE AUTO STOP'],
#  (22.621, 88.45): ['CITY CENTER 2 BUS STOP', 'CITY CENTER 2 AUTO STOP'],
#  (22.623, 88.441): ['CHINAR PARK BUS STOP', 'CHINAR PARK AUTO STOP'],
#  (22.6206, 88.439): ['LOKENATH MANDIR BUS STOP', 'LOKENATH MANDIR AUTO STOP'],
#  (22.5021, 88.38): ['SAHEED NAGAR BUS STOP', 'SAHEED NAGAR AUTO STOP'],
#  (22.6531, 88.331): ['SAPUIPARA BUS STOP', 'SAPUIPARA AUTO STOP'],
#  (22.7572, 88.317): ['DELHI ROAD BUS STOP', 'DELHI ROAD AUTO STOP'],
#  (22.68, 88.29): ['DANKUNI HOUSING BUS STOP', 'DANKUNI HOUSING AUTO STOP'],
#  (22.6553, 88.32334): ['RAJCHANDRAPUR BUS STOP', 'RAJCHANDRAPUR AUTO STOP'],
#  (22.6527, 88.339): ['BALLYHALT BUS STOP',
#   'BALLYHALT AUTO STOP',
#   'BALLY HALT STATION AUTO STOP',
#   'BALLY HALT AUTO STOP',
#   'NIBRA AUTO STOP',
#   'KAMDUNI MORE AUTO STOP',
#   'HIGHLAND PARK AUTO STOP',
#   '4NO BRIDGE AUTO STOP',
#   'HINDU KABRISTAN CROSSING ( TILJALA ) AUTO STOP'],
#  (22.63165, 88.35195): ['BELURMATH BUS STOP', 'BELURMATH AUTO STOP'],
#  (22.61997, 88.35338): ['DON BOSCO BUS STOP', 'DON BOSCO AUTO STOP'],
#  (22.60136, 88.34889): ['BANDHA GHAT / SALKIA CHOWRASTA BUS STOP',
#   'BANDHA GHAT / SALKIA CHOWRASTA AUTO STOP',
#   'BANDHA GHAT AUTO STOP'],
#  (22.59333, 88.3445): ['GOLABARAI PS / PILKHANA MORE BUS STOP',
#   'GOLABARAI PS / PILKHANA MORE AUTO STOP'],
#  (22.58365, 88.30769): ['NATUN RASTA BUS STOP', 'NATUN RASTA AUTO STOP'],
#  (22.58354, 88.31077): ['DALALPUKUR BUS STOP', 'DALALPUKUR AUTO STOP'],
#  (22.58217, 88.32085): ['SURKIKAL BUS STOP', 'SURKIKAL AUTO STOP'],
#  (22.89616, 88.42512): ['SHYAMASREE BUS STOP', 'SHYAMASREE AUTO STOP'],
#  (22.57671, 88.32697): ['KALIBABU BAZAR BUS STOP', 'KALIBABU BAZAR AUTO STOP'],
#  (22.57895, 88.33119): ['MALLICK FATAK BUS STOP',
#   'MALLICK FATAK / KADAMTALA AUTO STOP',
#   'MALLICK FATAK AUTO STOP'],
#  (22.56335, 88.3121): ['BATAITALA PHARI BUS STOP',
#   'BATAITALA PHARI AUTO STOP'],
#  (22.56233, 88.32297): ['KAZIPARA MORE / AVANI MALL BUS STOP',
#   'KAZIPARA MORE / AVANI MALL AUTO STOP'],
#  (22.5655, 88.32312): ['SHIBPUR BAZAR BUS STOP', 'SHIBPUR BAZAR AUTO STOP'],
#  (22.72893, 88.40284): ['DOPERIA BUS STOP', 'DOPERIA AUTO STOP'],
#  (22.466, 88.33865): ['KALYAN NAGAR BUS STOP', 'KALYAN NAGAR AUTO STOP'],
#  (22.70874, 88.38396): ['RASHMONI MORE BUS STOP', 'RASHMONI MORE AUTO STOP'],
#  (22.70072, 88.37844): ['SODEPUR STATION BUS STOP',
#   'SODEPUR STATION AUTO STOP'],
#  (22.67625, 88.37514): ['KAMARHATI BUS STOP', 'KAMARHATI AUTO STOP'],
#  (22.51365, 88.38105): ['RATHTALA MORE BUS STOP', 'RATHTALA MORE AUTO STOP'],
#  (22.65334, 88.36232): ['DAKSHINESHWAR BUS STOP', 'DAKSHINESHWAR AUTO STOP'],
#  (22.61163, 88.31063): ['BIRADINGI MORE BUS STOP', 'BIRADINGI MORE AUTO STOP'],
#  (22.59807, 88.32452): ['TIKIAPARA BUS STOP', 'TIKIAPARA AUTO STOP'],
#  (22.59732, 88.3283): ['BELILIOUS ROAD BUS STOP', 'BELILIOUS ROAD AUTO STOP'],
#  (22.68215, 88.27799): ['KALIPUR MORE BUS STOP', 'KALIPUR MORE AUTO STOP'],
#  (22.64822, 88.28268): ['JAGADISHPUR BUS STOP', 'JAGADISHPUR AUTO STOP'],
#  (22.63744, 88.29461): ['CHAMRAIL BUS STOP', 'CHAMRAIL AUTO STOP'],
#  (22.62763, 88.2913): ['EKSARA MORE BUS STOP', 'EKSARA MORE AUTO STOP'],
#  (22.62494, 88.29336): ['KONA MORE BUS STOP',
#   'KONA MORE AUTO STOP',
#   'KONA HIGH ROAD AUTO STOP',
#   'KONA EXPRESSWAY MORE AUTO STOP',
#   'KONA AUTO STOP',
#   'NABANNA AUTO STOP',
#   'SONDALIA STATION AUTO STOP',
#   'KHARIBARI AUTO STOP',
#   'CENTRAL GARAGE AUTO STOP',
#   'HOWRAH BRIDGE AUTO STOP',
#   'BHOJHERHAT AUTO STOP',
#   'LIBRARY MORE AUTO STOP'],
#  (22.6037621, 88.327565): ['BAMANGACHI BUS STOP', 'BAMANGACHI AUTO STOP'],
#  (22.597218, 88.337685): ['SALKIA CHOWRASTA / BANDHA GHAT BUS STOP',
#   'SALKIA CHOWRASTA / BANDHA GHAT AUTO STOP'],
#  (22.5659, 88.297): ['DANESH SHAIKH LANE BUS STOP',
#   'DANESH SHAIKH LANE AUTO STOP'],
#  (23.927376, 88.452312): ['AMTALA BUS STOP',
#   'AMTALA PHARI AUTO STOP',
#   'AMTALA AUTO STOP'],
#  (22.587601, 88.226173): ['ARGORI MORE BUS STOP', 'ARGORI MORE AUTO STOP'],
#  (22.594397, 88.242661): ['ANDUL BAZAR BUS STOP', 'ANDUL BAZAR AUTO STOP'],
#  (22.58317, 88.237656): ['CHUNAVATI BUS STOP', 'CHUNAVATI AUTO STOP'],
#  (23.361263, 88.602417): ['HANSKHALI POLE BUS STOP',
#   'HANSKHALI POLE AUTO STOP'],
#  (22.63158, 88.25927): ['MAKARDAHA BUS STOP', 'MAKARDAHA AUTO STOP'],
#  (22.6137, 88.2712): ['SALAP MORE BUS STOP',
#   'SALAP MORE AUTO STOP',
#   'SALAP AUTO STOP'],
#  (22.63, 88.6): ['BANKRA BAZAR BUS STOP', 'BANKRA BAZAR AUTO STOP'],
#  (22.606722, 88.303169): ['BALTIKURI BUS STOP', 'BALTIKURI AUTO STOP'],
#  (22.6021063, 88.3117739): ['DASNAGAR BUS STOP', 'DASNAGAR AUTO STOP'],
#  (22.295937, 88.027733): ['SHYAMPUR MORE BUS STOP', 'SHYAMPUR MORE AUTO STOP'],
#  (22.4604, 87.9997): ['MAHISHREKHA BUS STOP', 'MAHISHREKHA AUTO STOP'],
#  (22.4132, 87.9758): ['ANTILA BRIDGE BUS STOP', 'ANTILA BRIDGE AUTO STOP'],
#  (22.4195766, 87.9800183): ['INDRANARAYANPUR BUS STOP',
#   'MUGKALYAN AUTO STOP',
#   'DEORAH MORE AUTO STOP',
#   'SHASATI MORE AUTO STOP',
#   'KANTHALIBAR AUTO STOP',
#   'SHYAMPUR AUTO STOP',
#   'NARIKELABAR AUTO STOP',
#   'BHAGABANPUR AUTO STOP',
#   'SHRIKOLE MORE AUTO STOP',
#   'PANPUR MORE AUTO STOP',
#   'SHAMUKPOTA AUTO STOP',
#   'DHULORBANDH AUTO STOP',
#   'PATINAN AUTO STOP',
#   'KULEPAIRI AUTO STOP',
#   'KHEJURDAHA AUTO STOP',
#   'INDRALOK MORE AUTO STOP',
#   'DHAMISA AUTO STOP',
#   'BHAWANI BHAWAN AUTO STOP',
#   'MEHERANI AUTO STOP',
#   'CHOATIA AUTO STOP',
#   'KEMIA MORE AUTO STOP',
#   'CHAPABERIA AUTO STOP',
#   'CHALKI BAZAR AUTO STOP',
#   'PALLAGRAM AUTO STOP',
#   'MALIPOTA AUTO STOP',
#   'BARNABERIA AUTO STOP',
#   'JHAWDANGA AUTO STOP',
#   'KAHANKIA AUTO STOP',
#   'PABNAPARA AUTO STOP',
#   'PURANDARUR AUTO STOP',
#   'SUBIDPUR AUTO STOP',
#   'GARCHA AUTO STOP',
#   'BROAD STREET AUTO STOP',
#   'MAHISHGARI AUTO STOP',
#   'RAMLAL BAZAR AUTO STOP',
#   'BANTALA BAZAR AUTO STOP',
#   'CHOWBAGA AUTO STOP',
#   'GHOLA BAZAR AUTO STOP',
#   'MALAPARA / NIMTALA GHAT AUTO STOP',
#   'BARABAZAR / POSTA BAZAR AUTO STOP',
#   'KHASMALLICK AUTO STOP',
#   'HARINAVI AUTO STOP',
#   'MALLICKBAZAR AUTO STOP',
#   'KHANDALIA AUTO STOP',
#   'DHUKRIJHARA AUTO STOP',
#   'LENINNAGAR AUTO STOP',
#   'NOONGOLA AUTO STOP',
#   'MANDABTALA AUTO STOP',
#   'ANCHNA AUTO STOP',
#   'BISALAKSHMITALA AUTO STOP',
#   'SOBEDATALA AUTO STOP',
#   'BADIR MORE AUTO STOP',
#   'SAIHATI AUTO STOP',
#   ' PALBAZAR AUTO STOP',
#   'BHASHA 14NO AUTO STOP',
#   'KAJOLER MORE AUTO STOP',
#   ' UTTAR CHANDIPUR AUTO STOP',
#   'DAYARAMPUR BAZAR AUTO STOP',
#   'DAKSHIN BIRAMPUR AUTO STOP',
#   'CHOWDHURY CHAK AUTO STOP',
#   'JASHODA MORE AUTO STOP',
#   'INDRANARAYANPUR AUTO STOP'],
#  (21.3178, 87.982): ['BELPUKUR BUS STOP', 'BELPUKUR AUTO STOP'],
#  (22.9, 88.389999): ['HOGLASHI MORE BUS STOP', 'HOGLASHI MORE AUTO STOP'],
#  (22.4195766, 88.0173): ['KHARUBERIA BUS STOP', 'KHARUBERIA AUTO STOP'],
#  (22.3456, 88.0858): ['GARCHUMUK BUS STOP', 'GARCHUMUK AUTO STOP'],
#  (23.8286354, 87.9800183): ['RADHAPUR BUS STOP', 'RADHAPUR AUTO STOP'],
#  (22.5605, 88.2268): ['CHAPATALA BUS STOP', 'CHAPATALA AUTO STOP'],
#  (22.4195766, 88.2268): ['RAJGUNGE BUS STOP', 'RAJGUNGE AUTO STOP'],
#  (22.4195766, 87.72283): ['RADHADASHI BUS STOP', 'RADHADASHI AUTO STOP'],
#  (22.4195766, 88.51186): ['PODRA BAZAR BUS STOP', 'PODRA BAZAR AUTO STOP'],
#  (22.55721, 88.28182): ['NAZIRGUNGE BUS STOP', 'NAZIRGUNGE AUTO STOP'],
#  (22.59575, 87.94969): ['BHANDERGACHA BUS STOP', 'BHANDERGACHA AUTO STOP'],
#  (22.5312, 88.0551): ['SHIBERHANA BUS STOP', 'SHIBERHANA AUTO STOP'],
#  (22.5936716, 88.47356): ['BARGRAM MORE BUS STOP',
#   'BARGRAM MORE AUTO STOP',
#   'BOARDGHAR AUTO STOP',
#   'ECO PARK AUTO STOP'],
#  (22.4977092, 88.0698295): ['KARATBERIA BUS STOP', 'KARATBERIA AUTO STOP'],
#  (22.47873, 88.09502): ['NEEMDIGHI BUS STOP', 'NEEMDIGHI AUTO STOP'],
#  (22.7655, 88.4057): ['ICHAPUR MORE BUS STOP',
#   'ICHAPUR MORE AUTO STOP',
#   'BHAGABANPUR MORE AUTO STOP'],
#  (22.4012, 88.58296): ['PIFA BAZAR BUS STOP',
#   'PIFA BAZAR AUTO STOP',
#   'KHARAMPUR AUTO STOP',
#   'NIMCHI BAZAR AUTO STOP'],
#  (22.5232236, 88.8238936): ['BHEBIA CHOWRASTA BUS STOP',
#   'BHEBIA CHOWRASTA AUTO STOP'],
#  (22.485921, 88.385231): ['RAJAPUR BUS STOP', 'RAJAPUR AUTO STOP'],
#  (22.40117, 88.58293): ['NIMCHI BAZAR BUS STOP',
#   'PIFA BAZAR AUTO STOP',
#   'KHARAMPUR AUTO STOP',
#   'NIMCHI BAZAR AUTO STOP'],
#  (22.4912, 88.8403): ['AKHRATALA BUS STOP',
#   'AKHRATALA AUTO STOP',
#   'DAKSHIN AKHRATALA AUTO STOP'],
#  (22.68612, 88.20329): ['METEKHALI BUS STOP', 'METEKHALI AUTO STOP'],
#  (22.51371, 88.77767): ['CHAITAL GHAT BUS STOP', 'CHAITAL GHAT AUTO STOP'],
#  (22.43358, 88.76319): ['BOYERMARI BUS STOP', 'BOYERMARI AUTO STOP'],
#  (22.395, 88.78952): ['AGARHATI BUS STOP', 'AGARHATI AUTO STOP'],
#  (22.37261, 88.78441): ['SARBERIA BUS STOP', 'SARBERIA AUTO STOP'],
#  (22.84682, 88.63137): ['KALYANGARH BUS STOP', 'KALYANGARH AUTO STOP'],
#  (22.84832, 88.62506): ['KACHUA MORE BUS STOP', 'KACHUA MORE AUTO STOP'],
#  (22.83371, 88.61723): ['8NO. KALIBARI BUS STOP', '8NO. KALIBARI AUTO STOP'],
#  (22.84475, 88.57461): ['MAGURKHALI BUS STOP', 'MAGURKHALI AUTO STOP'],
#  (22.73285, 88.772): ['ISWARIGACHA BUS STOP', 'ISWARIGACHA AUTO STOP'],
#  (22.85638, 88.53167): ['AWALSIDDHI BUS STOP', 'AWALSIDDHI AUTO STOP'],
#  (22.86735, 88.53245): ['ADHATA MORE BUS STOP', 'ADHATA MORE AUTO STOP'],
#  (22.85981, 88.53459): ['SHIKRA MORE BUS STOP', 'SHIKRA MORE AUTO STOP'],
#  (22.76733, 88.48841): ['DARIAPUR BUS STOP', 'DARIAPUR AUTO STOP'],
# ...
#  (23.37409, 88.61429): ['MURAGACHA BUS STOP', 'MURAGACHA AUTO STOP'],
#  (22.58708, 88.42434): ['SALTLAKE 9NO. TANK BUS STOP',
#   'SALTLAKE 9NO. TANK AUTO STOP'],
#  (22.4719, 88.3991): ['206 BUS STAND BUS STOP', '206 BUS STAND AUTO STOP'],
#  (22.59769, 88.42399): ['SALTLAKE 7NO. TANK BUS STOP',
#   'SALTLAKE 7NO. TANK AUTO STOP',
#   'SALTLAKE 16NO. TANK AUTO STOP'],
#  (22.5957, 88.36): ['AHIRITOLA BUS STOP', 'AHIRITOLA AUTO STOP'],
#  (22.5922, 88.3567): ['JORABAGAN BUS STOP', 'JORABAGAN AUTO STOP'],
#  (22.35673, 88.43461): ['SHIBANIPITH BUS STOP', 'SHIBANIPITH AUTO STOP'],
#  (22.3596751, 88.4317758): ['BARUIPUR HOSPITAL BUS STOP',
#   'BARUIPUR HOSPITAL AUTO STOP'],
#  (22.3658265, 88.4310842): ['BARUIPUR STATION BUS STOP',
#   'BARUIPUR STATION AUTO STOP'],
#  (22.4938, 88.5842): ['PADMAPUKUR BUS STOP', 'PADMAPUKUR AUTO STOP'],
#  (22.4064698, 88.4088668): ['RAJPUR BAZAR BUS STOP', 'RAJPUR BAZAR AUTO STOP'],
#  (22.4366, 88.3992): ['NARENDRAPUR BUS STOP', 'NARENDRAPUR AUTO STOP'],
#  (22.4495, 88.3912): ['KAMALGAZI BUS STOP', 'KAMALGAZI AUTO STOP'],
#  (22.45403, 88.38787): ['MAHAMAYATALA BUS STOP', 'MAHAMAYATALA AUTO STOP'],
#  (22.51404, 88.35969): ['SOUTHERN AVENUE BUS STOP',
#   'SOUTHERN AVENUE AUTO STOP'],
#  (22.49524, 88.36026): ['DOORDARSHAN BHAWAN BUS STOP',
#   'DOORDARSHAN BHAWAN AUTO STOP'],
#  (22.6629, 88.4299): ['BIRATI STATION BUS STOP', 'BIRATI STATION AUTO STOP'],
#  (22.57677, 88.40905): ['SALTLAKE 12NO. TANK BUS STOP',
#   'SALTLAKE 12NO. TANK AUTO STOP'],
#  (22.59753, 88.4242): ['SALTLAKE 16NO. TANK BUS STOP',
#   'SALTLAKE 7NO. TANK AUTO STOP',
#   'SALTLAKE 16NO. TANK AUTO STOP'],
#  (22.84135, 88.62657): ['BUILDING MORE BUS STOP', 'BUILDING MORE AUTO STOP'],
#  (22.56572, 88.51426): ['SUKHOBRISHTI MORE BUS STOP',
#   'SUKHOBRISHTI MORE AUTO STOP',
#   'SUKHOBRISHTI AUTO STOP'],
#  (22.5603, 88.49146): ['KARIGARI BHAWAN BUS STOP',
#   'KARIGARI BHAWAN AUTO STOP',
#   'KARIGARI BHABAN AUTO STOP'],
#  (22.56004, 88.48991): ['U.E.M. CAMPUS BUS STOP', 'U.E.M. CAMPUS AUTO STOP'],
#  (22.61204, 88.52628): ['UNITECH GATE 1 BUS STOP', 'UNITECH GATE 1 AUTO STOP'],
#  (22.5732, 88.47293): ['NARKELBAGAN BUS STOP', 'NARKELBAGAN AUTO STOP'],
#  (22.58067, 88.46077): ['AXIS MALL BUS STOP', 'AXIS MALL AUTO STOP'],
#  (22.583, 88.4536): ['NEWTOWN BUS STOP',
#   'NEWTOWN AUTO STOP',
#   'NEW TOWN BUS STAND AUTO STOP'],
#  (22.5816, 88.4502): ['D.L.F. 1 BUS STOP', 'D.L.F. 1 AUTO STOP'],
#  (22.57158, 88.42004): ['NICCO PARK BUS STOP', 'NICCO PARK AUTO STOP'],
#  (22.55644587, 88.41821167): ['CHINGRIGHATA BUS STOP',
#   'CHINGRIGHATA AUTO STOP'],
#  (22.49074879, 88.40561531): ['MUKUNDAPUR BUS STOP', 'MUKUNDAPUR AUTO STOP'],
#  (22.48984612, 88.39469008): ['AJAYNAGAR BUS STOP',
#   'AJOYNAGAR AUTO STOP',
#   'NATURE PARK AUTO STOP',
#   'AJAYNAGAR AUTO STOP'],
#  (22.48310596, 88.39162914): ['HILAND PARK BUS STOP', 'HILAND PARK AUTO STOP'],
#  (22.53563772, 88.25529337): ['AKRA FATAK BUS STOP', 'AKRA FATAK AUTO STOP'],
#  (22.54213456, 88.26525312): ['BARTALA BAZAR BUS STOP',
#   'BARTALA BAZAR AUTO STOP'],
#  (22.54924127, 88.28523718): ['BICHALI GHAT BUS STOP',
#   'BICHALI GHAT AUTO STOP'],
#  (23.92556678, 88.36964604): ['TRIMOHINI BUS STOP', 'TRIMOHINI AUTO STOP'],
#  (22.6828994, 88.81236104): ['KHOLAPOTA BUS STOP', 'KHOLAPOTA AUTO STOP'],
#  (22.90849209, 88.70971821): ['GOPALPUR BUS STOP',
#   'GOPALPUR AUTO STOP',
#   'GOPALPUR MORE AUTO STOP'],
#  (22.54884685, 88.28247368): ['MATIA BRIDGE BUS STOP',
#   'MATIA BRIDGE AUTO STOP'],
#  (22.81474343, 88.85733869): ['SWARUPNAGAR BUS STOP', 'SWARUPNAGAR AUTO STOP'],
#  (22.695749, 88.68795173): ['BERACHAMPA BUS STOP', 'BERACHAMPA AUTO STOP'],
#  (22.68738302, 88.65371249): ['DEGANGA BUS STOP', 'DEGANGA AUTO STOP'],
#  (22.6976481, 88.63899715): ['KARTICKPUR BUS STOP', 'KARTICKPUR AUTO STOP'],
#  (22.51854587, 88.32233656): ['MAHJERHAT BUS STOP', 'MAHJERHAT AUTO STOP'],
#  (22.58507061, 88.37482942): [' MANIKTALA BUS STOP',
#   'SHOBHABAZAR AUTO STOP',
#   'MANIKTALA AUTO STOP',
#   ' MANIKTALA AUTO STOP'],
#  (22.53400016, 88.36434606): ['GURUSADAY ROAD BUS STOP',
#   'GURUSADAY ROAD AUTO STOP'],
#  (22.48591779, 88.41227423): ['NAYABAD BUS STOP', 'NAYABAD AUTO STOP'],
#  (22.48147829, 88.39266804): ['PEERLESS HOSPITAL BUS STOP',
#   'PEERLESS HOSPITAL AUTO STOP'],
#  (22.50939716, 88.30658721): ['PARNASREE BUS STOP', 'PARNASREE AUTO STOP'],
#  (22.50385235, 88.31862857): ['BEHALA PS BUS STOP', 'BEHALA PS AUTO STOP'],
#  (22.54835749, 88.4002015): ['DHAPA ROAD BUS STOP',
#   'BETHPUKUR AUTO STOP',
#   'DHAPA ROAD AUTO STOP',
#   'MATHPUKUR AUTO STOP'],
#  (22.59102988, 88.36274904): ['BEADON STREET BUS STOP',
#   'BEADON STREET AUTO STOP'],
#  (22.58696739, 88.35508304): ['MALAPARA BUS STOP', 'MALAPARA AUTO STOP'],
#  (22.58383138, 88.41563959): ['CENTRAL PARK BUS STOP',
#   'CENTRAL PARK AUTO STOP'],
#  (22.57070394, 88.4038522): ['KADAPARA BUS STOP', 'KADAPARA AUTO STOP'],
#  (22.57079564, 88.40035657): ['SUBHASH SAROBAR BUS STOP',
#   'SUBHASH SAROBAR AUTO STOP'],
#  (22.59432713, 88.47335539): ['ECO PARK BUS STOP',
#   'BARGRAM MORE AUTO STOP',
#   'BOARDGHAR AUTO STOP',
#   'ECO PARK AUTO STOP'],
#  (22.59113235, 88.48727219): ['ALIAH UNIVERSITY BUS STOP',
#   'ALIAH UNIVERSITY AUTO STOP'],
#  (22.58427599, 88.48954616): ['ECO SPACE BUS STOP',
#   'ECO SPACE AUTO STOP',
#   'ECOSPACE AUTO STOP',
#   'PASCHIM CHOWBHAGA AUTO STOP',
#   'JAMBERIA BRIDGE AUTO STOP'],
#  (22.57888698, 88.48567309): ['D.L.F. 2 BUS STOP', 'D.L.F. 2 AUTO STOP'],
#  (22.57692528, 88.48306591): ['UNITECH GATE 2 BUS STOP',
#   'UNITECH GATE 2 AUTO STOP',
#   'UNITECH GATE NO. 1 AUTO STOP',
#   'INFOSPACE AUTO STOP',
#   'UNITECH AUTO STOP'],
#  (22.66059126, 88.38968692): ['BELGHARIA STATION BUS STOP',
#   'BELGHORIA STATION AUTO STOP',
#   'BELGHARIA STATION AUTO STOP'],
#  (22.60138748, 88.34887828): ['BANDHA GHAT BUS STOP',
#   'BANDHA GHAT / SALKIA CHOWRASTA AUTO STOP',
#   'BANDHA GHAT AUTO STOP'],
#  (23.3597246, 88.60555073): ['HANSKHALI BUS STOP', 'HANSKHALI AUTO STOP'],
#  (22.59151391, 88.39997778): ['SALTLAKE P.N.B BUS STOP',
#   'SALTLAKE P.N.B AUTO STOP',
#   'PNB AUTO STOP',
#   'P.N.B. MORE AUTO STOP'],
#  (22.58134637, 88.29600118): ['BAKSARA BUS STOP',
#   'BAKSARA AUTO STOP',
#   'BAKSHARA AUTO STOP'],
#  (22.5773154, 88.30295081): ['BELEPOLE BUS STOP', 'BELEPOLE AUTO STOP'],
#  (22.66899514, 87.78298037): ['GHORADAHA BUS STOP', 'GHORADAHA AUTO STOP'],
#  (22.65402141, 88.09409402): ['MUNSHIRHAT BUS STOP', 'MUNSHIRHAT AUTO STOP'],
#  (22.6676942, 88.13237712): ['BARAGACHIA BUS STOP', 'BARAGACHIA AUTO STOP'],
#  (22.63420776, 88.22061711): ['DOMJUR BUS STOP', 'DOMJUR AUTO STOP'],
#  (22.61932669, 88.34821521): ['LILUAH STATION BUS STOP',
#   'LILUAH STATION AUTO STOP'],
#  (22.56951049, 88.31759613): ['MANDIRTALA BUS STOP', 'MANDIRTALA AUTO STOP'],
#  (22.56400228, 88.31818436): ['VIDYASAGAR SETU BUS STOP',
#   'VIDYASAGAR SETU AUTO STOP'],
#  (22.58942273, 88.3956412): ['E.M. BYPASS BUS STOP',
#   'E.M. BYPASS AUTO STOP',
#   'HUDCO MORE AUTO STOP'],
#  (22.54796287, 88.40043519): ['MATHPUKUR BUS STOP',
#   'BETHPUKUR AUTO STOP',
#   'DHAPA ROAD AUTO STOP',
#   'MATHPUKUR AUTO STOP'],
#  (22.552653, 88.40634991): ['METROPOLITAN BUS STOP', 'METROPOLITAN AUTO STOP'],
#  (22.1708682, 88.23355611): ['DALANGHATA BUS STOP', 'DALANGHATA AUTO STOP'],
#  (22.16899329, 88.25252306): ['HATUGUNGE BUS STOP', 'HATUGUNGE AUTO STOP'],
#  (22.16881761, 88.28230506): ['DEULAR MORE BUS STOP', 'DEULAR MORE AUTO STOP'],
#  (22.16016213, 88.32132678): ['MANDIRBAZAR BUS STOP', 'MANDIRBAZAR AUTO STOP'],
#  (22.15913832, 88.35940212): ['RATNESHWARPUR BUS STOP',
#   'RATNESHWARPUR AUTO STOP'],
#  (22.15441226, 88.37323839): ['PUKURIA HAT BUS STOP', 'PUKURIA HAT AUTO STOP'],
#  (22.14547059, 88.38852344): ['KARBALA MORE BUS STOP',
#   'KARBALA MORE AUTO STOP'],
#  (22.14229152, 88.39449942): ['MATHURAPUR STATION BUS STOP',
#   'MATHURAPUR STATION AUTO STOP'],
#  (22.38073273, 88.27228025): ['SOUTH BISHNUPUR BUS STOP',
#   'SOUTH BISHNUPUR AUTO STOP'],
#  (22.72934223, 88.35034327): ['KHOTIRBAZAR BUS STOP', 'KHOTIRBAZAR AUTO STOP'],
#  (22.60520659, 88.38394426): ['BELGACHI BUS STOP',
#   'BELGACHIA AUTO STOP',
#   'BELGACHI AUTO STOP'],
#  (22.12384742, 88.41924463): ['LALPUR BUS STOP', 'LALPUR AUTO STOP'],
#  (21.84094026, 88.41924463): ['KRISHNACHANDRAPUR BUS STOP',
#   'KRISHNACHANDRAPUR AUTO STOP'],
#  (22.0880408, 88.42751201): ['KASHINAGAR BUS STOP', 'KASHINAGAR AUTO STOP'],
#  (22.0384098, 88.42690116): ['COMPANIR THEK BUS STOP',
#   'COMPANIR THEK AUTO STOP'],
#  (22.76865191, 88.33018551): ['MAYRAMAHAL BUS STOP', 'MAYRAMAHAL AUTO STOP'],
#  (22.3230164, 87.81526409): ['HARIDASHPUR BUS STOP', 'HARIDASHPUR AUTO STOP'],
#  (22.27590254, 88.12632146): ['BHADURA BUS STOP',
#   'BHADURA AUTO STOP',
#   'GOUNDIA RAGHUNATHPUR AUTO STOP'],
#  (22.27600802, 88.12634516): ['GOUNDIA RAGHUNATHPUR BUS STOP',
#   'BHADURA AUTO STOP',
#   'GOUNDIA RAGHUNATHPUR AUTO STOP'],
#  (22.2578222, 88.16042304): ['PATESWARI MANDIR BUS STOP',
#   'PATESWARI MANDIR AUTO STOP'],
#  (22.25563217, 88.16729927): ['PITAMBARA BUS STOP', 'PITAMBARA AUTO STOP'],
#  (22.2482698, 88.18520128): ['SARISHA 246 MORE BUS STOP',
#   'SARISHA 246 MORE AUTO STOP'],
#  (22.23925347, 88.18419337): ['KALAGACHIA BUS STOP', 'KALAGACHIA AUTO STOP'],
#  (22.20619277, 88.18408461): ['KAPATHAT BUS STOP', 'KAPATHAT AUTO STOP'],
#  (22.19350953, 88.18970492): ['DIAMOND HARBOUR BUS STOP',
#   'DIAMOND HARBOUR AUTO STOP'],
#  (22.10563956, 87.86818471): ['BRINDABANPUR BUS STOP',
#   'BRINDABANPUR AUTO STOP'],
#  (22.86095103, 87.99540035): ['RAMNARAYANPURRAMNARAYANPUR BUS STOP',
#   'RAMNARAYANPURRAMNARAYANPUR AUTO STOP'],
#  (22.36101546, 88.11371017): ['BURUL BAZAR BUS STOP', 'BURUL BAZAR AUTO STOP'],
#  (22.36269591, 88.12441743): ['CHANDUA BAZAR BUS STOP',
#   'CHANDUA BAZAR AUTO STOP'],
#  (22.4911718, 88.40470402): ['UTTAR RAMKRISHNAPUR BUS STOP',
#   'UTTAR RAMKRISHNAPUR AUTO STOP',
#   'MAKRAMPUR AUTO STOP'],
#  (22.43956742, 88.4427345): ['GHASIARA BUS STOP', 'GHASIARA AUTO STOP'],
#  (22.43314139, 88.46296909): ['RAMCHANDRAPUR BUS STOP',
#   'RAMCHANDRAPUR AUTO STOP'],
#  (22.43104815, 88.47043992): ['ARAPANCH BUS STOP', 'ARAPANCH AUTO STOP'],
#  (22.42756066, 88.4722512): ['NATAGACHI BUS STOP', 'NATAGACHI AUTO STOP'],
#  (22.42343499, 88.50109032): ['TEMATHA BUS STOP', 'TEMATHA AUTO STOP'],
#  (22.49120612, 88.40453902): ['MAKRAMPUR BUS STOP',
#   'UTTAR RAMKRISHNAPUR AUTO STOP',
#   'MAKRAMPUR AUTO STOP'],
#  (22.42776135, 88.53033326): ['PRASADPUR BUS STOP', 'PRASADPUR AUTO STOP'],
#  (22.42873493, 88.53236643): ['SUNDIA BUS STOP', 'SUNDIA AUTO STOP'],
#  (22.43672949, 88.5688156): ['CHANDANESHWAR BUS STOP',
#   'CHANDANESHWAR AUTO STOP'],
#  (22.48465429, 88.29766399): ['JHAUTALA BUS STOP', 'JHAUTALA AUTO STOP'],
#  (22.43785901, 88.58190434): ['PATKELPOTA BUS STOP', 'PATKELPOTA AUTO STOP'],
#  (22.63279647, 88.45228039): ['SONDALIA BABLATALA BUS STOP',
#   'SONDALIA BABLATALA AUTO STOP'],
#  (22.4444, 88.59694): ['SITURI BUS STOP', 'SITURI AUTO STOP'],
#  (23.2417, 88.551): ['KALITALA BUS STOP', 'KALITALA AUTO STOP'],
#  (22.4513, 88.6097): ['BODRA BUS STOP', 'BODRA AUTO STOP'],
#  (22.48452, 88.60856): ['JAGULGACHI BUS STOP', 'JAGULGACHI AUTO STOP'],
#  (22.60027, 88.37419): ['POWER HOUSE BUS STOP',
#   'POWER HOUSE AUTO STOP',
#   'FARIAPUKUR AUTO STOP'],
#  (22.45045, 88.30604): ['IIMC HOSPITAL BUS STOP', 'IIMC HOSPITAL AUTO STOP'],
#  (22.44362, 88.42043): ['MISSION PALLY BUS STOP', 'MISSION PALLY AUTO STOP'],
#  (22.53088, 88.31248): ['SHIMULTALA BUS STOP', 'SHIMULTALA AUTO STOP'],
#  (22.55669, 88.65942): ['UTTAR CHANDIPUR BUS STOP',
#   'UTTAR CHANDIPUR AUTO STOP'],
#  (21.8593, 88.1415): ['KACHUBERIA BUS STOP', 'KACHUBERIA AUTO STOP'],
#  (22.08342, 88.24462): ['KULPI BUS STOP', 'KULPI AUTO STOP'],
#  (22.05482, 88.2487): ['DAKSHIN RAMKRISHNAPUR BUS STOP',
#   'DAKSHIN RAMKRISHNAPUR AUTO STOP'],
#  (22.03995, 88.23234): ['CHAKDULALPUR BUS STOP', 'CHAKDULALPUR AUTO STOP'],
#  (22.03551, 88.24567): ['KARANJALI BUS STOP', 'KARANJALI AUTO STOP'],
#  (22.43952, 88.3402): ['ONGC MORE BUS STOP', 'ONGC MORE AUTO STOP'],
#  (21.96909, 88.20811): ['NATUN RASTAR MORE BUS STOP',
#   'NATUN RASTAR MORE AUTO STOP'],
#  (21.872969, 88.199615): ['KAKDWIP STATION (BAMUNER MORE) BUS STOP',
#   'KAKDWIP STATION (BAMUNER MORE) AUTO STOP'],
#  (21.91187, 88.1856): ['KAKDWIP BUS STAND BUS STOP',
#   'KAKDWIP BUS STAND AUTO STOP'],
#  (21.97418, 88.35093): ['HOSPITAL MORE BUS STOP', 'HOSPITAL MORE AUTO STOP'],
#  (21.8879, 88.31916): ['GANGADHARPUR BUS STOP', 'GANGADHARPUR AUTO STOP'],
#  (21.83906, 88.31474): ['ADDHABAZAR BUS STOP', 'ADDHABAZAR AUTO STOP'],
#  (22.02766, 88.37016): ['MILAN MORE BUS STOP', 'MILAN MORE AUTO STOP'],
#  (22.0943, 88.27569): ['TANTIRHAT BUS STOP', 'TANTIRHAT AUTO STOP'],
#  (22.109867, 88.320869): ['LAKSHMIPOOL BUS STOP',
#   'LAKSHMIKANTAPUR STATION AUTO STOP',
#   'LAKSHMIPOOL AUTO STOP'],
#  (22.553953, 88.133702): ['GABBERIA BUS STOP', 'GABBERIA AUTO STOP'],
#  (22.6927, 88.19155): ['BHAGABATIPUR BUS STOP', 'BHAGABATIPUR AUTO STOP'],
#  (22.3653, 88.3751): [' DHOLAHAT MORE BUS STOP',
#   'SIDDHIBERIA AUTO STOP',
#   ' DHOLAHAT MORE AUTO STOP'],
#  (22.36969, 88.20969): ['PATHARBERIA MORE BUS STOP',
#   'PATHARBERIA MORE AUTO STOP'],
#  (22.49612, 88.2687): ['JAMALPUR MORE BUS STOP', 'JAMALPUR MORE AUTO STOP'],
#  (22.07178, 88.30313): ['JAGADISHPUR HOSPITAL BUS STOP',
#   'JAGADISHPUR HOSPITAL AUTO STOP'],
#  (22.76573, 88.40577): ['BHAGABANPUR MORE BUS STOP',
#   'ICHAPUR MORE AUTO STOP',
#   'BHAGABANPUR MORE AUTO STOP'],
#  (22.37462, 88.77633): ['SARASBERIA BUS STOP', 'SARASBERIA AUTO STOP'],
#  (21.98982, 88.36654): ['BRAHMANER MORE BUS STOP', 'BRAHMANER MORE AUTO STOP'],
#  (22.663, 88.3766): ['RATHTALA BUS STOP', 'RATHTALA AUTO STOP'],
#  (22.92695, 88.36787): ['GURUDASPUR HOSPITAL MORE BUS STOP',
#   'GURUDASPUR HOSPITAL MORE AUTO STOP'],
#  (22.78552, 88.85413): ['TENTULIA BAZAR BUS STOP', 'TENTULIA BAZAR AUTO STOP'],
#  (21.82177, 88.36798): ['RAMGANGA BDO OFFICE BUS STOP',
#   'RAMGANGA BDO OFFICE AUTO STOP'],
#  (21.81917, 88.37509): ['DHRUBABAZAR BUS STOP',
#   'DHRUBABAZAR AUTO STOP',
#   'DUTTABAZAR AUTO STOP'],
#  (22.29527, 88.09599): ['KALATALAHAT BUS STOP', 'KALATALAHAT AUTO STOP'],
#  (22.5029, 88.6156): ['GHATAKPUKUR BUS STOP',
#   'GHATAKPUKUR AUTO STOP',
#   'GANDHARBAPUR AUTO STOP'],
#  (23.0537, 87.7135): ['BAMUNIA BUS STOP', 'BAMUNIA AUTO STOP'],
#  (22.53226, 88.63055): ['CHANDIPUR BUS STOP', 'CHANDIPUR AUTO STOP'],
#  (22.448663, 88.867767): ['GHOSHPUR BUS STOP', 'GHOSHPUR AUTO STOP'],
#  (22.5959, 88.4007): ['GHUSHIGHATA BUS STOP',
#   'SREEBHUMI AUTO STOP',
#   'GHUSHIGHATA AUTO STOP'],
#  (22.57265, 88.69021): ['BAMANPUKUR BUS STOP', 'BAMANPUKUR AUTO STOP'],
#  (22.51855, 88.71746): ['KUSHANGRA BUS STOP', 'KUSHANGRA AUTO STOP'],
#  (22.508, 88.7275): ['MINAKHAN BUS STOP', 'MINAKHAN AUTO STOP'],
#  (22.5306884, 88.9335973): ['JOYGRAM BUS STOP', 'JOYGRAM AUTO STOP'],
#  (22.34483, 88.76331): ['SONAKHALI BUS STAND BUS STOP',
#   'GABBUNI AUTO STOP',
#   'CHARABIDYA AUTO STOP',
#   'DHURI BAZAR AUTO STOP',
#   'BAGARIA AUTO STOP',
#   'JALILPUR AUTO STOP',
#   'SONAKHALI BUS STAND AUTO STOP'],
#  (22.34469, 88.76346): ['CHARABIDYA BUS STOP',
#   'GABBUNI AUTO STOP',
#   'CHARABIDYA AUTO STOP',
#   'DHURI BAZAR AUTO STOP',
#   'BAGARIA AUTO STOP',
#   'JALILPUR AUTO STOP',
#   'SONAKHALI BUS STAND AUTO STOP'],
#  (22.3055, 88.7059): ['ATHAROBANKI BUS STOP', 'ATHAROBANKI AUTO STOP'],
#  (22.32145, 88.70511): ['AMJHARA BUS STOP', 'AMJHARA AUTO STOP'],
#  (22.305557, 88.420878): ['KANTHALBERIA BUS STOP', 'KANTHALBERIA AUTO STOP'],
#  (22.289, 88.6949): ['KALTALA BUS STOP', 'KALTALA AUTO STOP'],
#  (22.28876, 88.68521): ['BHANGANKHALI BUS STOP', 'BHANGANKHALI AUTO STOP'],
#  (22.6096, 88.4275): ['NARAYANTALA BUS STOP',
#   'BAGUIATI AUTO STOP',
#   'NARAYANTALA AUTO STOP',
#   'BAGUIHATI AUTO STOP'],
#  (21.88352, 88.52677): ['KULTALI BUS STOP', 'KULTALI AUTO STOP'],
#  (22.55164, 87.7669): ['UTTAR SONAKHALI BUS STOP',
#   'UTTAR SONAKHALI AUTO STOP'],
#  (22.2814, 88.24124): ['MASHAT MARKET BUS STOP', 'MASHAT MARKET AUTO STOP'],
#  (22.2317, 88.2733): ['USTHI BUS STOP', 'USTHI AUTO STOP'],
#  (22.37236, 88.35572): ['ADHARMANIK BUS STOP', 'ADHARMANIK AUTO STOP'],
#  (23.6858, 87.9353): ['PIRTALA BUS STOP', 'PIRTALA AUTO STOP'],
#  (23.3598, 88.2946): ['GHATUR MORE BUS STOP', 'GHATUR MORE AUTO STOP'],
#  (22.6661, 88.495): ['GOBRA MORE BUS STOP', 'GOBRA MORE AUTO STOP'],
#  (21.5633, 88.2682): ['BALAKHALI BUS STOP', 'BALAKHALI AUTO STOP'],
#  ...}

# %% [markdown]
# # Visualise In Graph

# %%
Nodes_x = []
Nodes_y = []

for key in Nodes:
    Nodes_x.append(key[0])
    Nodes_y.append(key[1])

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(Nodes_x,Nodes_y, marker='.', color='blue', label='Data Points', s=5, )
ax.set_xlabel('Latitude')
ax.set_ylabel('Longitude')
ax.set_title('Nodes')
ax.legend()
ax.grid()
plt.show()

# %%
for i in range(len(BusNodes)):
    if BusNodes[i][0] > 24 :
        print(BusNodes[i])

# %% [markdown]
# # Adjacency Matrix

# %%
BusMatrix_df = pd.read_csv('./Bus Matrix.csv')
AutoMatrix_df = pd.read_csv('./Auto Matrix.csv')
TrainMatrix_df = pd.read_csv('./Train Matrix.csv')
MetroMatrix_df = pd.read_csv('./Metro Matrix.csv')

# %%
def getConnection(Transport):
    NodePoints = []
    for i in range(Transport.shape[0]) :
        NodePoints.append((Transport['source'][i], Transport['dest'][i]))
    return NodePoints

# %%
BusMatrix = getConnection(BusMatrix_df)
MetroMatrix = getConnection(MetroMatrix_df)
TrainMatrix = getConnection(TrainMatrix_df)
AutoMatrix = getConnection(AutoMatrix_df)
# Out:
# '\nAutoMatrix = getConnection(AutoMatrix_df)\n'

# %% [markdown]
# BusMatrix[2]

# %%
'''
check either two point have any one transport among them or not 
'''
def connect(point1, point2): 
    #check for bus
    for pair in BusMatrix:
        con1 = (pair[0] in Nodes[point1] or pair[0] in Nodes[point2]) # if 'Bally Hal' is in point 1 or in point 2
        con2 = (pair[1] in Nodes[point1] or pair[1] in Nodes[point2]) # if 'Park Circus' is in point 1 or in point 2
        if con1 and con2:
            return True
    
#     for pair in BusMatrix:
#         con1 = (pair[0] in Nodes[point1] and pair[1] in Nodes[point2]) 
#         con2 = (pair[1] in Nodes[point1] and pair[0] in Nodes[point2])
#         if con1 and con2:
#             return True
    
    #check for Metro
    for pair in MetroMatrix:
        con1 = (pair[0] in Nodes[point1] or pair[0] in Nodes[point2])
        con2 = (pair[1] in Nodes[point1] or pair[1] in Nodes[point2])
        if con1 and con2:
            return True
#     for pair in MetroMatrix:
#         con1 = (pair[0] in Nodes[point1] and pair[1] in Nodes[point2])
#         con2 = (pair[1] in Nodes[point1] and pair[0] in Nodes[point2])
#         if con1 and con2:
#             return True
      
    #check for Train
    for pair in TrainMatrix:
        con1 = (pair[0] in Nodes[point1] or pair[0] in Nodes[point2])
        con2 = (pair[1] in Nodes[point1] or pair[1] in Nodes[point2])
        if con1 and con2:
            return True
#     for pair in TrainMatrix:
#         con1 = (pair[0] in Nodes[point1] and pair[1] in Nodes[point2])
#         con2 = (pair[1] in Nodes[point1] and pair[0] in Nodes[point2])
#         if con1 and con2:
#             return True
    
    #check for Auto
    for pair in AutoMatrix:
        con1 = (pair[0] in Nodes[point1] or pair[1] in Nodes[point2])
        con2 = (pair[1] in Nodes[point1] or pair[0] in Nodes[point2])
        if con1 and con2:
            return True
            
    return False

# %%
def getTransportData(point1, point2):
    pass

# %%
MatrixPoints = []
for node in Nodes:
    MatrixPoints.append(node)

# %%
'''
Making a (total node)x(total node) size matrix
'''
Matrix = [[0 for i in range(len(MatrixPoints))]for i in range(len(MatrixPoints))]

# %%
count = 0
for i in range(len(MatrixPoints)):
    for j in range(len(MatrixPoints)):
        if(connect(MatrixPoints[i],MatrixPoints[j])): #(1,2) || (2,3)
            Matrix[i][j] = 1
            count += 1
print(count)

# %% [markdown]
# # Visualize edges in graph

# %%
edge_x = []
edge_y = []
for i in range (len(Matrix)):
    for j in range(len(Matrix)):
        if Matrix[i][j] == 1: 
            edge_x.append(MatrixPoints[i][0])
            edge_y.append(MatrixPoints[i][1])
            edge_x.append(MatrixPoints[j][0])
            edge_y.append(MatrixPoints[j][1])

# %%
fig, ax = plt.subplots(figsize=(10, 6))
ax.scatter(Nodes_x,Nodes_y, marker='.', color='blue', label='Data Points', s=10, )
ax.plot(edge_x, edge_y, color='red', linestyle='-', linewidth=0.5, alpha=0.4)
ax.set_xlabel('Latitude')
ax.set_ylabel('Longitude')
ax.set_title('Nodes')
ax.legend()

plt.show()

# %% [markdown]
# # Find the Path

# %%
def get_geolocation_of(stop):
    for key, value in Nodes.items():
        if stop in value:
            return key

# %%
import networkx as nx

G_Time = nx.DiGraph()
G_Cost = nx.DiGraph()
G_Safety = nx.DiGraph()

# Metro
for i in range(MetroMatrix_df.shape[0]):
    src = str(get_geolocation_of(' '.join(word for word in MetroMatrix_df.iloc[i]['source'].split() if word)))
    dest = str(get_geolocation_of(' '.join(word for word in MetroMatrix_df.iloc[i]['dest'].split() if word)))
    
    # making bidirectonal path from A to B 
    G_Time.add_edge(src,dest, weight= MetroMatrix_df.iloc[i]['time']) # A -> B
    G_Time.add_edge(dest, src, weight= MetroMatrix_df.iloc[i]['time']) # B -> A

    G_Cost.add_edge(src,dest, weight= MetroMatrix_df.iloc[i]['cost']) # A -> B
    G_Cost.add_edge(dest, src, weight= MetroMatrix_df.iloc[i]['cost']) # B -> A

    G_Safety.add_edge(src,dest, weight= MetroMatrix_df.iloc[i]['safety']) # A -> B
    G_Safety.add_edge(dest, src, weight= MetroMatrix_df.iloc[i]['safety']) # B -> A

# Bus
for i in range(BusMatrix_df.shape[0]):
    src = str(get_geolocation_of(' '.join(word for word in BusMatrix_df.iloc[i]['source'].split() if word)))
    dest = str(get_geolocation_of(' '.join(word for word in BusMatrix_df.iloc[i]['dest'].split() if word)))
    
    G_Time.add_edge(src,dest, weight= BusMatrix_df.iloc[i]['time'])
    G_Time.add_edge(dest, src, weight= BusMatrix_df.iloc[i]['time'])

    G_Cost.add_edge(src,dest, weight= BusMatrix_df.iloc[i]['cost'])
    G_Cost.add_edge(dest, src, weight= BusMatrix_df.iloc[i]['cost'])

    G_Safety.add_edge(src,dest, weight= BusMatrix_df.iloc[i]['safety'])
    G_Safety.add_edge(dest, src, weight= BusMatrix_df.iloc[i]['safety'])
  
# Train
for i in range(TrainMatrix_df.shape[0]):
    src = str(get_geolocation_of(' '.join(word for word in TrainMatrix_df.iloc[i]['source'].split() if word)))
    dest = str(get_geolocation_of(' '.join(word for word in TrainMatrix_df.iloc[i]['dest'].split() if word)))
    
    G_Time.add_edge(src,dest, weight= TrainMatrix_df.iloc[i]['time'])
    G_Time.add_edge(dest,src, weight= TrainMatrix_df.iloc[i]['time'])

    G_Cost.add_edge(src,dest, weight= TrainMatrix_df.iloc[i]['cost'])
    G_Cost.add_edge(dest,src, weight= TrainMatrix_df.iloc[i]['cost'])

    G_Safety.add_edge(src,dest, weight= TrainMatrix_df.iloc[i]['safety'])
    G_Safety.add_edge(dest,src, weight= TrainMatrix_df.iloc[i]['safety'])
    
# Auto
for i in range(AutoMatrix_df.shape[0]):
    src = str(get_geolocation_of(' '.join(word for word in AutoMatrix_df.iloc[i]['source'].split() if word)))
    dest = str(get_geolocation_of(' '.join(word for word in AutoMatrix_df.iloc[i]['dest'].split() if word)))
    
    G_Time.add_edge(src,dest, weight= AutoMatrix_df.iloc[i]['time'])
    G_Time.add_edge(dest,src, weight= AutoMatrix_df.iloc[i]['time'])

    G_Cost.add_edge(src,dest, weight= AutoMatrix_df.iloc[i]['cost'])
    G_Cost.add_edge(dest,src, weight= AutoMatrix_df.iloc[i]['cost'])

    G_Safety.add_edge(src,dest, weight= AutoMatrix_df.iloc[i]['safety'])
    G_Safety.add_edge(dest,src, weight= AutoMatrix_df.iloc[i]['safety'])

def FindPath_wrt_Cost(s, d):
    try:
        shortest_path = nx.shortest_path(G_Cost, source= str(get_geolocation_of(s)), target=str(get_geolocation_of(d)), weight="weight")
    except:
        shortest_path = "Route is out of Network"
    return shortest_path

def Find_path_Time(s, d):
    try:
        shortest_path = nx.shortest_path(G_Time, source= get_geolocation_of(s), target=get_geolocation_of(d), weight="weight")
    except:
        shortest_path = "Route is out of Network"
    return shortest_path

def Find_path_Safety(s, d):
    try:
        shortest_path = nx.shortest_path(G_Safety, source= get_geolocation_of(s), target=get_geolocation_of(d), weight="weight")
    except:
        shortest_path = "Route is out of Network"
    return shortest_path

# %%
path_for_graph = [literal_eval(x) for x in FindPath_wrt_Cost('SODEPUR TRAIN STOP', 'SHYAMBAZAR METRO STOP')]
path_for_user = [Nodes[x] for x in path_for_graph]
print("path=>", path_for_user)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 2
#       1 path_for_graph = [literal_eval(x) for x in FindPath_wrt_Cost('SODEPUR TRAIN STOP', 'SHYAMBAZAR METRO STOP')]
# ----> 2 path_for_user = [Nodes[x] for x in path_for_graph]
#       3 print("path=>", path_for_user)
#
# Cell In[29], line 2, in <listcomp>(.0)
#       1 path_for_graph = [literal_eval(x) for x in FindPath_wrt_Cost('SODEPUR TRAIN STOP', 'SHYAMBAZAR METRO STOP')]
# ----> 2 path_for_user = [Nodes[x] for x in path_for_graph]
#       3 print("path=>", path_for_user)
#
# KeyError: None

# %%
def station_to_point(s):
    for key, value in Nodes.items():
        for station in value:
            escaped_string = re.escape(s)
            regex_pattern = f'^{escaped_string}'
            pattern = re.compile(regex_pattern, re.MULTILINE)
            matches = pattern.findall(station)
            if bool(matches):
                return key

# %%
fig, ax = plt.subplots(figsize=(10, 6))
p = []
for x in path_for_graph: 
    p.append(station_to_point(x))
    
zpoint_x = [x[0] for x in p]
zpoint_y = [y[1] for y in p]

# ax.scatter(Nodes_x, Nodes_y, label='other nodes', color='lightgray', alpha=0.5)
# ax.plot(edge_x, edge_y, color='pink', linestyle='-', linewidth=0.1, alpha=0.4)
ax.scatter(zpoint_x, zpoint_y, label='route', color='blue', s=20)
ax.plot(zpoint_x, zpoint_y, color='green', linestyle='-', linewidth=0.9)
ax.scatter(zpoint_x[0], zpoint_y[0], marker='^', color='red', label='Source', s=100)
ax.scatter(zpoint_x[len(zpoint_x)-1], zpoint_y[len(zpoint_y)-1], marker='*', color='black', label='Destination', s=100)

xlo = min(zpoint_x) - 0.01
xhi = max(zpoint_x) + 0.01
ylo = min(zpoint_y) - 0.01
yhi = max(zpoint_y) + 0.01

plt.xlim(xlo, xhi)
plt.ylim(ylo, yhi)

plt.title('dedicated path')
plt.legend()

# Show the plot
plt.show()
